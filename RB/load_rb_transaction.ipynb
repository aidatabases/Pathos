# %% [markdown]
# # Querying Postgres

# %%
from pathos_config import *

# %% [markdown]
# ## Selecting Relevant Dimensions based on Master Dim Table + Filtering based on (Active for reporting)

# %% [markdown]
# ### reference schema

# %%
for i in range(len(ref_table_list)):
    sample_var = ref_table_list[i]
    print(sample_var)
    vars()[sample_var]= load_data(ref_table_list[i], 'pathos_reference_common_schema', connection)
# Out:
# pathos_ref_emotions
# pathos_ref_sectors
# pathos_ref_drivers
# pathos_ref_drivers_sectors_mapping
# pathos_ref_clients
# pathos_ref_release_version_table

# %%
# Applying Filter
pathos_ref_drivers_sectors_mapping = pathos_ref_drivers_sectors_mapping.loc[pathos_ref_drivers_sectors_mapping['sector_reporting_flag']=='Y']

# %% [markdown]
# ### dimension schema

# %%
for i in range(len(dim_table_list_rb)):
    sample_var = dim_table_list_rb[i]
    print(sample_var)
    vars()[sample_var]= load_data(dim_table_list_rb[i], 'pathos_rb_schema', connection)
# Out:
# pathos_cl_master_dim_mapping
# pathos_cl_master_manufacturer
# pathos_cl_master_brand
# pathos_cl_master_prd_ver
# pathos_cl_master_time
# pathos_cl_master_product
# pathos_cl_master_gmo
# pathos_cl_master_source
# pathos_cl_master_channel
# pathos_cl_master_country
# pathos_cl_master_personas

# %%
pathos_cl_master_prd_ver
# Out:
#    dim_val_id dim_value_name                    dim_value_desc dim_active_reporting dim_active_processsing child_record  parent_record_id  hierarchy_level                       created_on created_by                       updated_on updated_by
# 0  910010.000           V2.1    2.3 version from Jan 15th 2021                    N                      N            N        -99999.000            1.000 2021-05-25 13:52:06.137444+00:00     System 2021-05-25 13:52:06.137444+00:00     System
# 1  910011.000           V2.2  2.4 version from March 15th 2021                    Y                      Y            N        -99999.000            1.000 2021-05-25 13:52:06.137444+00:00     System 2021-05-25 13:52:06.137444+00:00     System

# %%
# Applying Filter
try:
    pathos_cl_master_brand = active_filter(pathos_cl_master_brand)
except:
    print('not available')
try:
    pathos_cl_master_manufacturer = active_filter(pathos_cl_master_manufacturer)
except:
    print('not available')
try:
    pathos_cl_master_prd_ver = active_filter(pathos_cl_master_prd_ver)
except:
    print('not available')

try:
    pathos_cl_master_dim_mapping = active_filter(pathos_cl_master_dim_mapping)
except:
    print('not available')
        
try:
    pathos_cl_master_time = active_filter(pathos_cl_master_time)
except:
    print('not available')
        
try:
    pathos_cl_master_product = active_filter(pathos_cl_master_product)
except:
    print('not available')
        
try:
    pathos_cl_master_gmo = active_filter(pathos_cl_master_gmo)
except:
    print('not available')
        
try:
    pathos_cl_master_source = active_filter(pathos_cl_master_source)
except:
    print('not available')
    
try:
    pathos_cl_master_country = active_filter(pathos_cl_master_country)
except:
    print('not available')
    
try:
    pathos_cl_master_channel = active_filter(pathos_cl_master_channel)
except:
    print('not available')

# %%
pathos_cl_master_prd_ver
# Out:
#    dim_val_id dim_value_name                    dim_value_desc dim_active_reporting dim_active_processsing child_record  parent_record_id  hierarchy_level                       created_on created_by                       updated_on updated_by
# 1  910011.000           V2.2  2.4 version from March 15th 2021                    Y                      Y            N        -99999.000            1.000 2021-05-25 13:52:06.137444+00:00     System 2021-05-25 13:52:06.137444+00:00     System

# %%
# Initializing version_id and Version
try:
    version_id = pathos_cl_master_prd_ver['dim_val_id'].iloc[0]
    version    = pathos_cl_master_prd_ver['dim_value_name'].iloc[0]
except:
    print('not available')

# %%
version_id
# Out:
# 910011.0

# %% [markdown]
# ### generic schema

# %%
connection = pg.connect('postgresql://aidatabases:Aidatabases#@65.1.96.15:5432/pathos_db')

# %%
initial_data = psql.read_sql('SELECT * FROM pathos_rb_schema.rb_initial_data', connection)

try:
    initial_data['MANUFACTURER'].replace({'rb Health': 'RB Health','Rb Health': 'RB Health', 'rB Health': 'RB Health'}, inplace=True)
except:
    print('not available')

# %%
initial_data
# Out:
#           Id                                      review_id MANUFACTURER BRAND                   SUBBRAND                    Product                               CATEGORY Country       Date    FORM                   GMO MILK SOURCE          ORGANIC CLAIM  Rating SEGMENT   Source Source type SUB-SEGMENT Channel
# 0          0                            139703062_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-02  Powder  with a Non GMO Claim         Cow  Without Organic claim   4.000  Infant  walmart     Reviews   Solutions  Online
# 1          1  7ad72964-96e6-496e-b544-7903bcd57b65_53926215    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-08  Powder  with a Non GMO Claim         Cow  Without Organic claim   4.000  Infant   target     Reviews   Solutions  Online
# 2          2  d5ac519f-218a-4554-b666-9de96bca5af2_53926215    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-08  Powder  with a Non GMO Claim         Cow  Without Organic claim   3.000  Infant   target     Reviews   Solutions  Online
# 3          3  efe60a77-b737-49aa-bd7b-92cbd3bd7a6a_53926215    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-08  Powder  with a Non GMO Claim         Cow  Without Organic claim   1.000  Infant   target     Reviews   Solutions  Online
# 4          4                            139703127_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-09  Powder  with a Non GMO Claim         Cow  Without Organic claim   5.000  Infant  walmart     Reviews   Solutions  Online
# ...      ...                                            ...          ...   ...                        ...                        ...                                    ...     ...        ...     ...                   ...         ...                    ...     ...     ...      ...         ...         ...     ...
# 15360  15360                            156145177_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2020-10-05  Powder  with a Non GMO Claim         Cow  Without Organic claim   1.000  Infant  walmart     Reviews   Solutions    Mail
# 15361  15361                            141987732_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2020-12-02  Powder  with a Non GMO Claim         Cow  Without Organic claim   2.000  Infant  walmart     Reviews   Solutions    Mail
# 15362  15362                            157991835_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2020-12-06  Powder  with a Non GMO Claim         Cow  Without Organic claim   5.000  Infant  walmart     Reviews   Solutions    Mail
# 15363  15363                                      236571120         Yili  Yili                  Yili Gold                  Yili Gold  Infant Formula And Children Nutrition     USA 2019-03-30  powder      With a GMO Claim         cow     With Organic Claim   5.000  infant      jet     Reviews     routine    Mail
# 15364  15364                                      237661600         Yili  Yili                  Yili Gold                  Yili Gold  Infant Formula And Children Nutrition     USA 2019-04-25  powder      With a GMO Claim         cow     With Organic Claim   5.000  infant      jet     Reviews     routine    Mail
#
# [15365 rows x 19 columns]

# %% [markdown]
# ## Dimensions based on filters

# %%
try:    
    pathos_cl_master_dim_mapping = pathos_cl_master_dim_mapping.loc[pathos_cl_master_dim_mapping['dim_active_reporting']=='Y']
    k=[]
    l=[]
    for i, j in zip(pathos_cl_master_dim_mapping['dim_sql'], pathos_cl_master_dim_mapping['dimension_desc']):
        k.append(j)
        l.append(i)
        print(k)
        print(l)

    for i in range(len(k)):
        sample_var = k[i]
        #print(sample_var)
        vars()[sample_var] = psql.read_sql(l[i], connection)
        vars()[sample_var] = vars()[sample_var].loc[vars()[sample_var]['dim_active_reporting']=='Y']
        
except:
    print('not available')
# Out:
# ['Version']
# ['SELECT * FROM pathos_rb_schema.pathos_cl_master_prd_ver']
# ['Version', 'Time']
# ['SELECT * FROM pathos_rb_schema.pathos_cl_master_prd_ver', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_time']
# ['Version', 'Time', 'Manufacturer']
# ['SELECT * FROM pathos_rb_schema.pathos_cl_master_prd_ver', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_time', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_manufacturer']
# ['Version', 'Time', 'Manufacturer', 'Brand']
# ['SELECT * FROM pathos_rb_schema.pathos_cl_master_prd_ver', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_time', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_manufacturer', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_brand']
# ['Version', 'Time', 'Manufacturer', 'Brand', 'Product']
# ['SELECT * FROM pathos_rb_schema.pathos_cl_master_prd_ver', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_time', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_manufacturer', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_brand', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_product']
# ['Version', 'Time', 'Manufacturer', 'Brand', 'Product', 'GMO']
# ['SELECT * FROM pathos_rb_schema.pathos_cl_master_prd_ver', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_time', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_manufacturer', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_brand', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_product', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_gmo']
# ['Version', 'Time', 'Manufacturer', 'Brand', 'Product', 'GMO', 'Source']
# ['SELECT * FROM pathos_rb_schema.pathos_cl_master_prd_ver', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_time', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_manufacturer', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_brand', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_product', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_gmo', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_source']
# ['Version', 'Time', 'Manufacturer', 'Brand', 'Product', 'GMO', 'Source', 'Channel']
# ['SELECT * FROM pathos_rb_schema.pathos_cl_master_prd_ver', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_time', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_manufacturer', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_brand', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_product', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_gmo', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_source', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_channel']
# ['Version', 'Time', 'Manufacturer', 'Brand', 'Product', 'GMO', 'Source', 'Channel', 'Country']
# ['SELECT * FROM pathos_rb_schema.pathos_cl_master_prd_ver', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_time', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_manufacturer', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_brand', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_product', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_gmo', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_source', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_channel', 'SELECT * FROM pathos_rb_schema.pathos_cl_master_country']

# %% [markdown]
# # Transaction Table

# %% [markdown]
# # Adding Relevant Dimension ID'

# %%
try:
    initial_data['year'] = pd.DatetimeIndex(initial_data['Date']).year
    #initial_data['year'] = initial_data.year.apply(str)
except:
    print('not available')

# %%
try:
    initial_data['year'] = initial_data.year.apply(str)
    s = initial_data.year.replace(pathos_cl_master_time.set_index('dim_value_name')['dim_val_id'])
    initial_data['time_id'] = s
except:
    print('not available')

# %%
initial_data
# Out:
#           Id                                      review_id MANUFACTURER BRAND                   SUBBRAND                    Product                               CATEGORY Country       Date    FORM                   GMO MILK SOURCE          ORGANIC CLAIM  Rating SEGMENT   Source Source type SUB-SEGMENT Channel  year    time_id
# 0          0                            139703062_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-02  Powder  with a Non GMO Claim         Cow  Without Organic claim   4.000  Infant  walmart     Reviews   Solutions  Online  2016 810014.000
# 1          1  7ad72964-96e6-496e-b544-7903bcd57b65_53926215    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-08  Powder  with a Non GMO Claim         Cow  Without Organic claim   4.000  Infant   target     Reviews   Solutions  Online  2016 810014.000
# 2          2  d5ac519f-218a-4554-b666-9de96bca5af2_53926215    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-08  Powder  with a Non GMO Claim         Cow  Without Organic claim   3.000  Infant   target     Reviews   Solutions  Online  2016 810014.000
# 3          3  efe60a77-b737-49aa-bd7b-92cbd3bd7a6a_53926215    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-08  Powder  with a Non GMO Claim         Cow  Without Organic claim   1.000  Infant   target     Reviews   Solutions  Online  2016 810014.000
# 4          4                            139703127_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-09  Powder  with a Non GMO Claim         Cow  Without Organic claim   5.000  Infant  walmart     Reviews   Solutions  Online  2016 810014.000
# ...      ...                                            ...          ...   ...                        ...                        ...                                    ...     ...        ...     ...                   ...         ...                    ...     ...     ...      ...         ...         ...     ...   ...        ...
# 15360  15360                            156145177_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2020-10-05  Powder  with a Non GMO Claim         Cow  Without Organic claim   1.000  Infant  walmart     Reviews   Solutions    Mail  2020 810010.000
# 15361  15361                            141987732_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2020-12-02  Powder  with a Non GMO Claim         Cow  Without Organic claim   2.000  Infant  walmart     Reviews   Solutions    Mail  2020 810010.000
# 15362  15362                            157991835_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2020-12-06  Powder  with a Non GMO Claim         Cow  Without Organic claim   5.000  Infant  walmart     Reviews   Solutions    Mail  2020 810010.000
# 15363  15363                                      236571120         Yili  Yili                  Yili Gold                  Yili Gold  Infant Formula And Children Nutrition     USA 2019-03-30  powder      With a GMO Claim         cow     With Organic Claim   5.000  infant      jet     Reviews     routine    Mail  2019 810011.000
# 15364  15364                                      237661600         Yili  Yili                  Yili Gold                  Yili Gold  Infant Formula And Children Nutrition     USA 2019-04-25  powder      With a GMO Claim         cow     With Organic Claim   5.000  infant      jet     Reviews     routine    Mail  2019 810011.000
#
# [15365 rows x 21 columns]

# %%
#REPLACING BRAND NAME WITH BRAND ID
try:
    s = initial_data.BRAND.replace(pathos_cl_master_brand.set_index('dim_value_name')['dim_val_id'])
    initial_data['brand_id'] = s
except:
    print('not available')

# %%
#REPLACING MANUFACTURER NAME WITH MANUFACTURER ID
try:
    s = initial_data.MANUFACTURER.replace(pathos_cl_master_manufacturer.set_index('dim_value_name')['dim_val_id'])
    initial_data['manufacturer_id'] = s
except:
    print('not available')

# %%
#REPLACING PRODUCT NAME WITH PRODUCT ID
try:
    s = initial_data.Product.replace(pathos_cl_master_product.set_index('dim_value_name')['dim_val_id'])
    initial_data['product_id'] = s
except:
    print('not available')

# %%
#REPLACING GMO NAME WITH GMO ID
try:
    initial_data.GMO.replace('with a Non GMO Claim','With a Non GMO Claim', inplace = True )
    s = initial_data.GMO.replace(pathos_cl_master_gmo.set_index('dim_value_name')['dim_val_id'])
    initial_data['gmo_id'] = s
except:
    print('not available')

# %%
#REPLACING SOURCE NAME WITH SOURCE ID
try:
    s = initial_data.Source.replace(pathos_cl_master_source.set_index('dim_value_name')['dim_val_id'])
    initial_data['source_id'] = s
except:
    print('not available')

# %%
#REPLACING CHANNEL NAME WITH CHANNEL ID
try:
    s = initial_data.Channel.replace(pathos_cl_master_channel.set_index('dim_value_name')['dim_val_id'])
    initial_data['channel_id'] = s
except:
    print('not available')

# %%
#REPLACING CHANNEL NAME WITH CHANNEL ID
try:
    s = initial_data.Country.replace(pathos_cl_master_country.set_index('dim_value_name')['dim_val_id'])
    initial_data['country_id'] = s
except:
    print('not available')

# %% [markdown]
# # Applying filters to Main DataFrame

# %%
try:
    available_manufacturer = list(pathos_cl_master_manufacturer['dim_val_id'])
except:
    print('not available')
        
try:
    available_brand = list(pathos_cl_master_brand['dim_val_id'])
except:
    print('not available')
        
try:
    available_product = list(pathos_cl_master_product['dim_val_id'])
except:
    print('not available')
        
try:
    available_gmo = list(pathos_cl_master_gmo['dim_val_id'])
except:
    print('not available')
        
try:
    available_source = list(pathos_cl_master_source['dim_val_id'])
except:
    print('not available')
        
try:
    available_time_id = list(pathos_cl_master_time['dim_val_id'])
except:
    print('not available')
        
try:
    available_channel_id = list(pathos_cl_master_channel['dim_val_id'])
except:
    print('not available')

# %% [markdown]
# ### Applying Filter

# %%
try:
    initial_data = initial_data.loc[initial_data['manufacturer_id'].isin (available_manufacturer)]
except:
    print('not available')
        
try:
    initial_data = initial_data.loc[initial_data['brand_id'].isin (available_brand)]
except:
    print('not available')
        
try:
    initial_data = initial_data.loc[initial_data['product_id'].isin (available_product)]
except:
    print('not available')

try:
    initial_data = initial_data.loc[initial_data['gmo_id'].isin (available_gmo)]
except:
    print('not available')

try:
    initial_data = initial_data.loc[initial_data['source_id'].isin (available_source)]
except:
    print('not available')

try:
    initial_data = initial_data.loc[initial_data['time_id'].isin (available_time_id)]
except:
    print('not available')

try:
    initial_data = initial_data.loc[initial_data['channel_id'].isin (available_channel_id)]
except:
    print('not available')

# %%
initial_data
# Out:
#           Id                                      review_id MANUFACTURER BRAND                   SUBBRAND                    Product                               CATEGORY Country       Date    FORM                   GMO MILK SOURCE          ORGANIC CLAIM  Rating SEGMENT   Source Source type SUB-SEGMENT Channel  year    time_id   brand_id manufacturer_id  product_id     gmo_id  source_id  channel_id  country_id
# 0          0                            139703062_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-02  Powder  With a Non GMO Claim         Cow  Without Organic claim   4.000  Infant  walmart     Reviews   Solutions  Online  2016 810014.000 610007.000      510003.000 7100094.000 810003.000 910003.000   55001.000   77001.000
# 1          1  7ad72964-96e6-496e-b544-7903bcd57b65_53926215    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-08  Powder  With a Non GMO Claim         Cow  Without Organic claim   4.000  Infant   target     Reviews   Solutions  Online  2016 810014.000 610007.000      510003.000 7100094.000 810003.000 910006.000   55001.000   77001.000
# 2          2  d5ac519f-218a-4554-b666-9de96bca5af2_53926215    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-08  Powder  With a Non GMO Claim         Cow  Without Organic claim   3.000  Infant   target     Reviews   Solutions  Online  2016 810014.000 610007.000      510003.000 7100094.000 810003.000 910006.000   55001.000   77001.000
# 3          3  efe60a77-b737-49aa-bd7b-92cbd3bd7a6a_53926215    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-08  Powder  With a Non GMO Claim         Cow  Without Organic claim   1.000  Infant   target     Reviews   Solutions  Online  2016 810014.000 610007.000      510003.000 7100094.000 810003.000 910006.000   55001.000   77001.000
# 4          4                            139703127_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2016-01-09  Powder  With a Non GMO Claim         Cow  Without Organic claim   5.000  Infant  walmart     Reviews   Solutions  Online  2016 810014.000 610007.000      510003.000 7100094.000 810003.000 910003.000   55001.000   77001.000
# ...      ...                                            ...          ...   ...                        ...                        ...                                    ...     ...        ...     ...                   ...         ...                    ...     ...     ...      ...         ...         ...     ...   ...        ...        ...             ...         ...        ...        ...         ...         ...
# 15360  15360                            156145177_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2020-10-05  Powder  With a Non GMO Claim         Cow  Without Organic claim   1.000  Infant  walmart     Reviews   Solutions    Mail  2020 810010.000 610007.000      510003.000 7100094.000 810003.000 910003.000   55002.000   77001.000
# 15361  15361                            141987732_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2020-12-02  Powder  With a Non GMO Claim         Cow  Without Organic claim   2.000  Infant  walmart     Reviews   Solutions    Mail  2020 810010.000 610007.000      510003.000 7100094.000 810003.000 910003.000   55002.000   77001.000
# 15362  15362                            157991835_327388827    RB Health  Enfa  Enfamil Enspire Gentlease  Enfamil Enspire Gentlease  Infant Formula And Children Nutrition     USA 2020-12-06  Powder  With a Non GMO Claim         Cow  Without Organic claim   5.000  Infant  walmart     Reviews   Solutions    Mail  2020 810010.000 610007.000      510003.000 7100094.000 810003.000 910003.000   55002.000   77001.000
# 15363  15363                                      236571120         Yili  Yili                  Yili Gold                  Yili Gold  Infant Formula And Children Nutrition     USA 2019-03-30  powder      With a GMO Claim         cow     With Organic Claim   5.000  infant      jet     Reviews     routine    Mail  2019 810011.000 610029.000      510012.000  710027.000 810002.000 910004.000   55002.000   77001.000
# 15364  15364                                      237661600         Yili  Yili                  Yili Gold                  Yili Gold  Infant Formula And Children Nutrition     USA 2019-04-25  powder      With a GMO Claim         cow     With Organic Claim   5.000  infant      jet     Reviews     routine    Mail  2019 810011.000 610029.000      510012.000  710027.000 810002.000 910004.000   55002.000   77001.000
#
# [10624 rows x 28 columns]

# %% [markdown]
# ## Adding Version ID in main table

# %%
try:    
    initial_data['version_id'] = version_id
    initial_data['version'] = version
except:
        print('not available')

# %% [markdown]
# ## Dropping unnecessary columns

# %%
initial_data.drop(['version','Channel', 'Country','MANUFACTURER', 'BRAND', 'SUBBRAND', 'Product', 'CATEGORY', 'FORM', 
                   'GMO', 'MILK SOURCE', 'ORGANIC CLAIM', 'Rating', 'SEGMENT', 'Source', 'Source type', 
                   'SUB-SEGMENT'], axis=1, inplace=True, errors='ignore')

# %%
initial_data.columns
# Out:
# Index(['Id', 'review_id', 'Date', 'year', 'time_id', 'brand_id', 'manufacturer_id', 'product_id', 'gmo_id', 'source_id', 'channel_id', 'country_id', 'version_id'], dtype='object')

# %% [markdown]
# # Renaming Column names to match with Schema Syntax

# %%
rename_dict = {'Id':'pathos_transaction_id', 
                'Date':'date'
                }

# %%
initial_data.rename(columns=rename_dict, inplace=True)

# %%
initial_data.columns
# Out:
# Index(['pathos_transaction_id', 'review_id', 'date', 'year', 'time_id', 'brand_id', 'manufacturer_id', 'product_id', 'gmo_id', 'source_id', 'channel_id', 'country_id', 'version_id'], dtype='object')

# %% [markdown]
# # Transaction table

# %%
connection = pg.connect('postgresql://aidatabases:Aidatabases#@65.1.96.15:5432/pathos_db')

engine = create_engine('postgresql://aidatabases:Aidatabases#@65.1.96.15:5432/pathos_db')

# %%
try:
    truncate_table(table_name= 'rb_transaction_table', schema = 'pathos_rb_schema')
except:
    print("not available")

# %%
push_table_pgres(initial_data, df_name = 'rb_transaction_table', schema= 'pathos_rb_schema')

# %%
initial_data
# Out:
#        pathos_transaction_id                                      review_id       date  year    time_id   brand_id manufacturer_id  product_id     gmo_id  source_id  channel_id  country_id  version_id
# 0                          0                            139703062_327388827 2016-01-02  2016 810014.000 610007.000      510003.000 7100094.000 810003.000 910003.000   55001.000   77001.000  910011.000
# 1                          1  7ad72964-96e6-496e-b544-7903bcd57b65_53926215 2016-01-08  2016 810014.000 610007.000      510003.000 7100094.000 810003.000 910006.000   55001.000   77001.000  910011.000
# 2                          2  d5ac519f-218a-4554-b666-9de96bca5af2_53926215 2016-01-08  2016 810014.000 610007.000      510003.000 7100094.000 810003.000 910006.000   55001.000   77001.000  910011.000
# 3                          3  efe60a77-b737-49aa-bd7b-92cbd3bd7a6a_53926215 2016-01-08  2016 810014.000 610007.000      510003.000 7100094.000 810003.000 910006.000   55001.000   77001.000  910011.000
# 4                          4                            139703127_327388827 2016-01-09  2016 810014.000 610007.000      510003.000 7100094.000 810003.000 910003.000   55001.000   77001.000  910011.000
# ...                      ...                                            ...        ...   ...        ...        ...             ...         ...        ...        ...         ...         ...         ...
# 15360                  15360                            156145177_327388827 2020-10-05  2020 810010.000 610007.000      510003.000 7100094.000 810003.000 910003.000   55002.000   77001.000  910011.000
# 15361                  15361                            141987732_327388827 2020-12-02  2020 810010.000 610007.000      510003.000 7100094.000 810003.000 910003.000   55002.000   77001.000  910011.000
# 15362                  15362                            157991835_327388827 2020-12-06  2020 810010.000 610007.000      510003.000 7100094.000 810003.000 910003.000   55002.000   77001.000  910011.000
# 15363                  15363                                      236571120 2019-03-30  2019 810011.000 610029.000      510012.000  710027.000 810002.000 910004.000   55002.000   77001.000  910011.000
# 15364                  15364                                      237661600 2019-04-25  2019 810011.000 610029.000      510012.000  710027.000 810002.000 910004.000   55002.000   77001.000  910011.000
#
# [10624 rows x 13 columns]

# %%
import os
os.system('jupyter nbconvert --to python load_rb_transaction.ipynb')
# Out:
# 0
