# %%
from pathos_config import *

summary_table = load_data('rb_summary_table', 'pathos_rb_schema', connection)

# %%
table = load_data('rb_tree_manufacturer_product', 'pathos_rb_schema', connection)

# %%
# summary_table_manufacturer = summary_table.groupby(['manufacturer']).emotional_engagement_score.mean().sort_values().head(3)
# summary_table_manufacturer = summary_table_manufacturer.to_frame().reset_index()
# manufacturer_list = list(summary_table_manufacturer['manufacturer'])

# %%
# column_list = ['manufacturer', 'brand', 'product', 'emotional_engagement_score']

# %%
# df_brand = pd.DataFrame(columns=['manufacturer', 'brand', 'emotional_engagement_score'])
# for i in range(len(manufacturer_list)):
#     sample_var_manufacturer = manufacturer_list[i]
#     #print(sample_var_manufacturer)
#     vars()[sample_var_manufacturer] = summary_table.loc[summary_table['manufacturer']==sample_var_manufacturer]
#     vars()[sample_var_manufacturer] = vars()[sample_var_manufacturer][column_list]
#     df_manufacturer_brand = vars()[sample_var_manufacturer].groupby(['brand']).emotional_engagement_score.mean().sort_values().head(3)
#     df_manufacturer_brand = df_manufacturer_brand.to_frame().reset_index()
#     brand_list = list(df_manufacturer_brand['brand'])
#     #print(df_manufacturer_brand)
#     df_manufacturer_brand['manufacturer'] = sample_var_manufacturer
#     df_brand = df_brand.append(df_manufacturer_brand, ignore_index = True)  
#     return df_brand

# %%
rb_tree = pd.DataFrame()

# %%
rb_tree.loc[0,['child', 'root', 'emotional_engagement_score']] = ['RB', np.nan,np.nan]

# %%
rb_tree
# Out:
#   child  root  emotional_engagement_score
# 0    RB   NaN                         NaN

# %%
def filter_aggregator_level2(level1, level2, dataframe):
    column_list = ['manufacturer', 'brand', 'product', 'emotional_engagement_score']
    summary_table_level1 = dataframe.groupby([level1]).emotional_engagement_score.mean().sort_values().head(3)
    summary_table_level1 = summary_table_level1.to_frame().reset_index()
    level1_list = list(summary_table_level1[level1])
    df_level2 = pd.DataFrame(columns=[level1, level2, 'emotional_engagement_score'])
    for i in range(len(level1_list)):
        sample_var_level1 = level1_list[i]
        #print(sample_var_manufacturer)
        vars()[sample_var_level1] = dataframe.loc[dataframe[level1]==sample_var_level1]
        vars()[sample_var_level1] = vars()[sample_var_level1][column_list]
        df_level1_level2 = vars()[sample_var_level1].groupby([level2]).emotional_engagement_score.mean().sort_values().head(3)
        df_level1_level2 = df_level1_level2.to_frame().reset_index()
        level2_list = list(df_level1_level2[level2])
        #print(df_manufacturer_brand)
        df_level1_level2[level1] = sample_var_level1
        df_level2 = df_level2.append(df_level1_level2, ignore_index = True)  
    return df_level2

# %%
df_level2 = filter_aggregator_level2(level1='manufacturer', level2='brand', dataframe=summary_table)

# %%
df_level2.rename(columns={'manufacturer':'root', 'brand':'child'}, inplace=True)

# %%
def filter_aggregator_level3(level1, level2,level3, dataframe): 
    column_list = ['manufacturer', 'brand', 'product', 'emotional_engagement_score']
    summary_table_level1 = dataframe.groupby([level1]).emotional_engagement_score.mean().sort_values().head(3)
    summary_table_level1 = summary_table_level1.to_frame().reset_index()
    level1_list = list(summary_table_level1[level1])
    df_level3 = pd.DataFrame(columns=[level1, level2, level3,'emotional_engagement_score'])
    level_list = []
    for i in range(len(level1_list)):
        sample_var_level1 = level1_list[i]
        print(sample_var_level1)
        vars()[sample_var_level1] = dataframe.loc[dataframe[level1]==sample_var_level1]
        vars()[sample_var_level1] = vars()[sample_var_level1][column_list]
        df_level1_level2 = vars()[sample_var_level1].groupby([level2]).emotional_engagement_score.mean().sort_values().head(3)
        df_level1_level2 = df_level1_level2.to_frame().reset_index()
        level2_list = list(df_level1_level2[level2])
        #df_level1_level2[level1] = sample_var_level1
        #level_list.append(level2_list)
        
        for i in range(len(level2_list)):
            sample_var_level2 = level2_list[i]
            print(sample_var_level2)
            vars()[sample_var_level2] = dataframe.loc[dataframe[level2]==sample_var_level2]
            vars()[sample_var_level2] = vars()[sample_var_level2][column_list]
            df_level2_level3 = vars()[sample_var_level2].groupby([level3]).emotional_engagement_score.mean().sort_values().head(3)
            df_level2_level3 = df_level2_level3.to_frame().reset_index()
            level3_list = list(df_level2_level3[level3])
            df_level2_level3[level1] = sample_var_level1
            df_level2_level3[level2] = sample_var_level2
            df_level3 = df_level3.append(df_level2_level3, ignore_index = True) 
    return df_level3

# %%
df_level3 = filter_aggregator_level3(level1='manufacturer', level2='brand',level3 = 'product', dataframe=summary_table)
# Out:
# RB Health
# Nutramigen
# Enfa
# Danone
# Neocate
# Happy Brands
# Abbott
# Abbott Grow
# Elecare
# Similac

# %%
df_level3.drop(columns={'manufacturer'}, inplace=True)

# %%
df_level3.rename(columns={'brand':'root', 'product':'child'}, inplace=True)

# %%
def filter_aggregator_level3(level1, level2,level3, dataframe): 
    column_list = ['manufacturer', 'brand', 'product', 'emotional_engagement_score']
    summary_table_level1 = dataframe.groupby([level1]).emotional_engagement_score.mean().sort_values().head(3)
    summary_table_level1 = summary_table_level1.to_frame().reset_index()
    level1_list = list(summary_table_level1[level1])
    df_level3 = pd.DataFrame(columns=[level1, level2, level3,'emotional_engagement_score'])
    level_list = []
    for i in range(len(level1_list)):
        sample_var_level1 = level1_list[i]
        print(sample_var_level1)
        vars()[sample_var_level1] = dataframe.loc[dataframe[level1]==sample_var_level1]
        vars()[sample_var_level1] = vars()[sample_var_level1][column_list]
        df_level1_level2 = vars()[sample_var_level1].groupby([level2]).emotional_engagement_score.mean().sort_values().head(3)
        df_level1_level2 = df_level1_level2.to_frame().reset_index()
        level2_list = list(df_level1_level2[level2])
        #df_level1_level2[level1] = sample_var_level1
        #level_list.append(level2_list)
        
        for i in range(len(level2_list)):
            sample_var_level2 = level2_list[i]
            print(sample_var_level2)
            vars()[sample_var_level2] = dataframe.loc[dataframe[level2]==sample_var_level2]
            vars()[sample_var_level2] = vars()[sample_var_level2][column_list]
            df_level2_level3 = vars()[sample_var_level2].groupby([level3]).emotional_engagement_score.mean().sort_values().head(3)
            df_level2_level3 = df_level2_level3.to_frame().reset_index()
            level3_list = list(df_level2_level3[level3])
            df_level2_level3[level1] = sample_var_level1
            df_level2_level3[level2] = sample_var_level2
            df_level3 = df_level3.append(df_level2_level3, ignore_index = True) 
    return df_level3

# %%
def filter_aggregator_drivers(level1, level2,level3, dataframe): 
    column_list = ['manufacturer', 'brand', 'product', 'emotional_engagement_score']
    drivers_list = ['drivers_personalization_score', 'drivers_positivity_score', 'drivers_well_being_score', 'drivers_exciting_score', 'drivers_belonging_score', 'drivers_sustainability_score', 'drivers_security_score', 'drivers_convenience_score',
       'drivers_care_score', 'drivers_timeliness_score', 'drivers_respect_score', 'drivers_knowledge_score', 'drivers_fairness_score', 'drivers_channel_satisfaction_score', 'drivers_outcome_score', 'drivers_communication_score', 'drivers_ease_of_access_score', 'drivers_future_issues_score', 'drivers_competence_score', 'drivers_extra_mile_score', 'drivers_waiting_time_score', 'drivers_appeal_score', 'drivers_preferred_chanel_score', 'drivers_freshness_score', 'drivers_trust_score', 'drivers_regret_score', 'drivers_relationship_score', 'drivers_innovative_score', 'drivers_value_for_money_score', 'drivers_packaging_score']
    added_driver_list = column_list + drivers_list
    summary_table_level1 = dataframe.groupby([level1]).emotional_engagement_score.mean().sort_values().head(3)
    summary_table_level1 = summary_table_level1.to_frame().reset_index()
    level1_list = list(summary_table_level1[level1])
    df_level4 = pd.DataFrame(columns=[level1, level2, level3,'emotional_engagement_score'])
    level_list = []
    for i in range(len(level1_list)):
        sample_var_level1 = level1_list[i]
        print(sample_var_level1)
        vars()[sample_var_level1] = dataframe.loc[dataframe[level1]==sample_var_level1]
        vars()[sample_var_level1] = vars()[sample_var_level1][added_driver_list]
        df_level1_level2 = vars()[sample_var_level1].groupby([level2]).emotional_engagement_score.mean().sort_values().head(3)
        df_level1_level2 = df_level1_level2.to_frame().reset_index()
        level2_list = list(df_level1_level2[level2])
        #df_level1_level2[level1] = sample_var_level1
        #level_list.append(level2_list)
        
        for i in range(len(level2_list)):
            sample_var_level2 = level2_list[i]
            #print(sample_var_level2)
            vars()[sample_var_level2] = dataframe.loc[dataframe[level2]==sample_var_level2]
            vars()[sample_var_level2] = vars()[sample_var_level2][added_driver_list]
            df_level2_level3 = vars()[sample_var_level2].groupby([level3]).emotional_engagement_score.mean().sort_values().head(3)
            df_level2_level3 = df_level2_level3.to_frame().reset_index()
            level3_list = list(df_level2_level3[level3])
#             df_level2_level3[level1] = sample_var_level1
#             df_level2_level3[level2] = sample_var_level2
#             df_level3 = df_level3.append(df_level2_level3, ignore_index = True)
            for i in range(len(level3_list)):
                sample_var_level3= level3_list[i]
                print(sample_var_level3)
                vars()[sample_var_level3] = dataframe.loc[dataframe[level3]==sample_var_level3]
                vars()[sample_var_level3] = vars()[sample_var_level3][added_driver_list]
                
                vars()[sample_var_level3].dropna(axis=1, how='all', inplace=True)
                common_drivers = list(set(drivers_list).intersection(vars()[sample_var_level3].columns))
                vars()[sample_var_level3]= vars()[sample_var_level3][common_drivers].mean().sort_values().head(3)
                df_level3_level4 = vars()[sample_var_level3].to_frame().reset_index()
                df_level3_level4.reset_index(inplace=True)
                df_level3_level4[level3] = sample_var_level3
                df_level4 = df_level4.append(df_level3_level4, ignore_index = True)
                
                
                #print(df_level3_level4)

            
    return df_level4

# %%
df_level4 = filter_aggregator_drivers(level1='manufacturer', level2='brand',level3 = 'product', dataframe=summary_table)
# Out:
# RB Health
# Nutramigen HA
# Nutramigen
# Nutramigen Puramino
# Enfamil D-Vi-Sol Liquid Vitamin D Supplement
# Nutramigen Lgg
# Enfamil Prosobee
# Danone
# NEOCATE
# Happy Baby
# Abbott
# Grow
# Elecare
# Similac 2-Fl
# Similac For Spit Up
# Similac Pro-Total Comfort

# %%
df_level4
# Out:
#    manufacturer brand                                       product emotional_engagement_score  level_0                               index      0
# 0           NaN   NaN                                 Nutramigen HA                        NaN    0.000              drivers_fairness_score -0.012
# 1           NaN   NaN                                 Nutramigen HA                        NaN    1.000             drivers_freshness_score -0.010
# 2           NaN   NaN                                 Nutramigen HA                        NaN    2.000        drivers_ease_of_access_score  0.000
# 3           NaN   NaN                                    Nutramigen                        NaN    0.000             drivers_packaging_score -0.026
# 4           NaN   NaN                                    Nutramigen                        NaN    1.000            drivers_timeliness_score -0.002
# 5           NaN   NaN                                    Nutramigen                        NaN    2.000        drivers_ease_of_access_score  0.000
# 6           NaN   NaN                           Nutramigen Puramino                        NaN    0.000          drivers_waiting_time_score  0.000
# 7           NaN   NaN                           Nutramigen Puramino                        NaN    1.000               drivers_respect_score  0.000
# 8           NaN   NaN                           Nutramigen Puramino                        NaN    2.000         drivers_future_issues_score  0.000
# 9           NaN   NaN  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                        NaN    0.000             drivers_freshness_score -0.460
# 10          NaN   NaN  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                        NaN    1.000            drivers_well_being_score -0.107
# 11          NaN   NaN  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                        NaN    2.000            drivers_positivity_score -0.061
# 12          NaN   NaN                                Nutramigen Lgg                        NaN    0.000             drivers_freshness_score -0.126
# 13          NaN   NaN                                Nutramigen Lgg                        NaN    1.000                  drivers_care_score -0.028
# 14          NaN   NaN                                Nutramigen Lgg                        NaN    2.000               drivers_outcome_score -0.011
# 15          NaN   NaN                              Enfamil Prosobee                        NaN    0.000                 drivers_trust_score -0.079
# 16          NaN   NaN                              Enfamil Prosobee                        NaN    1.000           drivers_convenience_score -0.061
# 17          NaN   NaN                              Enfamil Prosobee                        NaN    2.000              drivers_fairness_score -0.038
# 18          NaN   NaN                                       NEOCATE                        NaN    0.000  drivers_channel_satisfaction_score -0.040
# 19          NaN   NaN                                       NEOCATE                        NaN    1.000             drivers_packaging_score -0.030
# 20          NaN   NaN                                       NEOCATE                        NaN    2.000              drivers_fairness_score -0.023
# 21          NaN   NaN                                    Happy Baby                        NaN    0.000              drivers_fairness_score -0.002
# 22          NaN   NaN                                    Happy Baby                        NaN    1.000                 drivers_trust_score -0.002
# 23          NaN   NaN                                    Happy Baby                        NaN    2.000  drivers_channel_satisfaction_score -0.000
# 24          NaN   NaN                                          Grow                        NaN    0.000             drivers_freshness_score -0.049
# 25          NaN   NaN                                          Grow                        NaN    1.000                  drivers_care_score -0.026
# 26          NaN   NaN                                          Grow                        NaN    2.000            drivers_positivity_score -0.023
# 27          NaN   NaN                                       Elecare                        NaN    0.000             drivers_freshness_score -0.113
# 28          NaN   NaN                                       Elecare                        NaN    1.000                  drivers_care_score -0.042
# 29          NaN   NaN                                       Elecare                        NaN    2.000              drivers_fairness_score -0.029
# 30          NaN   NaN                                  Similac 2-Fl                        NaN    0.000             drivers_freshness_score -0.381
# 31          NaN   NaN                                  Similac 2-Fl                        NaN    1.000  drivers_channel_satisfaction_score -0.052
# 32          NaN   NaN                                  Similac 2-Fl                        NaN    2.000               drivers_outcome_score -0.014
# 33          NaN   NaN                           Similac For Spit Up                        NaN    0.000            drivers_well_being_score -0.336
# 34          NaN   NaN                           Similac For Spit Up                        NaN    1.000            drivers_positivity_score -0.119
# 35          NaN   NaN                           Similac For Spit Up                        NaN    2.000               drivers_outcome_score -0.076
# 36          NaN   NaN                     Similac Pro-Total Comfort                        NaN    0.000             drivers_freshness_score -0.087
# 37          NaN   NaN                     Similac Pro-Total Comfort                        NaN    1.000             drivers_packaging_score -0.036
# 38          NaN   NaN                     Similac Pro-Total Comfort                        NaN    2.000  drivers_channel_satisfaction_score -0.030

# %%
df_level4.drop(columns={'manufacturer', 'brand', 'emotional_engagement_score', 'level_0'}, inplace=True)

# %%
df_level4.rename(columns={'product':'root', 'index':'child', 0:'emotional_engagement_score'}, inplace=True)

# %%
df_level4
# Out:
#                                             root                               child  emotional_engagement_score
# 0                                  Nutramigen HA              drivers_fairness_score                      -0.012
# 1                                  Nutramigen HA             drivers_freshness_score                      -0.010
# 2                                  Nutramigen HA        drivers_ease_of_access_score                       0.000
# 3                                     Nutramigen             drivers_packaging_score                      -0.026
# 4                                     Nutramigen            drivers_timeliness_score                      -0.002
# 5                                     Nutramigen        drivers_ease_of_access_score                       0.000
# 6                            Nutramigen Puramino          drivers_waiting_time_score                       0.000
# 7                            Nutramigen Puramino               drivers_respect_score                       0.000
# 8                            Nutramigen Puramino         drivers_future_issues_score                       0.000
# 9   Enfamil D-Vi-Sol Liquid Vitamin D Supplement             drivers_freshness_score                      -0.460
# 10  Enfamil D-Vi-Sol Liquid Vitamin D Supplement            drivers_well_being_score                      -0.107
# 11  Enfamil D-Vi-Sol Liquid Vitamin D Supplement            drivers_positivity_score                      -0.061
# 12                                Nutramigen Lgg             drivers_freshness_score                      -0.126
# 13                                Nutramigen Lgg                  drivers_care_score                      -0.028
# 14                                Nutramigen Lgg               drivers_outcome_score                      -0.011
# 15                              Enfamil Prosobee                 drivers_trust_score                      -0.079
# 16                              Enfamil Prosobee           drivers_convenience_score                      -0.061
# 17                              Enfamil Prosobee              drivers_fairness_score                      -0.038
# 18                                       NEOCATE  drivers_channel_satisfaction_score                      -0.040
# 19                                       NEOCATE             drivers_packaging_score                      -0.030
# 20                                       NEOCATE              drivers_fairness_score                      -0.023
# 21                                    Happy Baby              drivers_fairness_score                      -0.002
# 22                                    Happy Baby                 drivers_trust_score                      -0.002
# 23                                    Happy Baby  drivers_channel_satisfaction_score                      -0.000
# 24                                          Grow             drivers_freshness_score                      -0.049
# 25                                          Grow                  drivers_care_score                      -0.026
# 26                                          Grow            drivers_positivity_score                      -0.023
# 27                                       Elecare             drivers_freshness_score                      -0.113
# 28                                       Elecare                  drivers_care_score                      -0.042
# 29                                       Elecare              drivers_fairness_score                      -0.029
# 30                                  Similac 2-Fl             drivers_freshness_score                      -0.381
# 31                                  Similac 2-Fl  drivers_channel_satisfaction_score                      -0.052
# 32                                  Similac 2-Fl               drivers_outcome_score                      -0.014
# 33                           Similac For Spit Up            drivers_well_being_score                      -0.336
# 34                           Similac For Spit Up            drivers_positivity_score                      -0.119
# 35                           Similac For Spit Up               drivers_outcome_score                      -0.076
# 36                     Similac Pro-Total Comfort             drivers_freshness_score                      -0.087
# 37                     Similac Pro-Total Comfort             drivers_packaging_score                      -0.036
# 38                     Similac Pro-Total Comfort  drivers_channel_satisfaction_score                      -0.030

# %%
df_level1 = summary_table.groupby(['manufacturer']).emotional_engagement_score.mean().sort_values().head(3)
df_level1 = df_level1.to_frame().reset_index()

# %%
df_level1['root']= 'RB'

# %%
df_level1.rename(columns={'manufacturer':'child'}, inplace=True)

# %%
rb_tree = rb_tree.append(df_level1, ignore_index=True)

# %%
rb_tree = rb_tree.append(df_level2, ignore_index=True)

# %%
rb_tree = rb_tree.append(df_level3, ignore_index=True)

# %%
rb_tree = rb_tree.append(df_level4, ignore_index=True)

# %%
rb_tree
# Out:
#                                            child                                          root  emotional_engagement_score
# 0                                             RB                                           NaN                         NaN
# 1                                      RB Health                                            RB                       0.181
# 2                                         Danone                                            RB                       0.190
# 3                                         Abbott                                            RB                       0.228
# 4                                     Nutramigen                                     RB Health                       0.153
# 5                                           Enfa                                     RB Health                       0.182
# 6                                        Neocate                                        Danone                      -0.494
# 7                                   Happy Brands                                        Danone                       0.229
# 8                                    Abbott Grow                                        Abbott                      -0.766
# 9                                        Elecare                                        Abbott                      -0.303
# 10                                       Similac                                        Abbott                       0.151
# 11                                 Nutramigen HA                                    Nutramigen                       0.039
# 12                                    Nutramigen                                    Nutramigen                       0.211
# 13                           Nutramigen Puramino                                    Nutramigen                       0.613
# 14  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                                          Enfa                      -1.220
# 15                                Nutramigen Lgg                                          Enfa                      -0.797
# 16                              Enfamil Prosobee                                          Enfa                      -0.572
# 17                                       NEOCATE                                       Neocate                      -0.494
# 18                                    Happy Baby                                  Happy Brands                       0.229
# 19                                          Grow                                   Abbott Grow                      -0.766
# 20                                       Elecare                                       Elecare                      -0.303
# 21                                  Similac 2-Fl                                       Similac                      -0.903
# 22                           Similac For Spit Up                                       Similac                      -0.780
# 23                     Similac Pro-Total Comfort                                       Similac                      -0.395
# 24                        drivers_fairness_score                                 Nutramigen HA                      -0.012
# 25                       drivers_freshness_score                                 Nutramigen HA                      -0.010
# 26                  drivers_ease_of_access_score                                 Nutramigen HA                       0.000
# 27                       drivers_packaging_score                                    Nutramigen                      -0.026
# 28                      drivers_timeliness_score                                    Nutramigen                      -0.002
# 29                  drivers_ease_of_access_score                                    Nutramigen                       0.000
# 30                    drivers_waiting_time_score                           Nutramigen Puramino                       0.000
# 31                         drivers_respect_score                           Nutramigen Puramino                       0.000
# 32                   drivers_future_issues_score                           Nutramigen Puramino                       0.000
# 33                       drivers_freshness_score  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                      -0.460
# 34                      drivers_well_being_score  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                      -0.107
# 35                      drivers_positivity_score  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                      -0.061
# 36                       drivers_freshness_score                                Nutramigen Lgg                      -0.126
# 37                            drivers_care_score                                Nutramigen Lgg                      -0.028
# 38                         drivers_outcome_score                                Nutramigen Lgg                      -0.011
# 39                           drivers_trust_score                              Enfamil Prosobee                      -0.079
# 40                     drivers_convenience_score                              Enfamil Prosobee                      -0.061
# 41                        drivers_fairness_score                              Enfamil Prosobee                      -0.038
# 42            drivers_channel_satisfaction_score                                       NEOCATE                      -0.040
# 43                       drivers_packaging_score                                       NEOCATE                      -0.030
# 44                        drivers_fairness_score                                       NEOCATE                      -0.023
# 45                        drivers_fairness_score                                    Happy Baby                      -0.002
# 46                           drivers_trust_score                                    Happy Baby                      -0.002
# 47            drivers_channel_satisfaction_score                                    Happy Baby                      -0.000
# 48                       drivers_freshness_score                                          Grow                      -0.049
# 49                            drivers_care_score                                          Grow                      -0.026
# 50                      drivers_positivity_score                                          Grow                      -0.023
# 51                       drivers_freshness_score                                       Elecare                      -0.113
# 52                            drivers_care_score                                       Elecare                      -0.042
# 53                        drivers_fairness_score                                       Elecare                      -0.029
# 54                       drivers_freshness_score                                  Similac 2-Fl                      -0.381
# 55            drivers_channel_satisfaction_score                                  Similac 2-Fl                      -0.052
# 56                         drivers_outcome_score                                  Similac 2-Fl                      -0.014
# 57                      drivers_well_being_score                           Similac For Spit Up                      -0.336
# 58                      drivers_positivity_score                           Similac For Spit Up                      -0.119
# 59                         drivers_outcome_score                           Similac For Spit Up                      -0.076
# 60                       drivers_freshness_score                     Similac Pro-Total Comfort                      -0.087
# 61                       drivers_packaging_score                     Similac Pro-Total Comfort                      -0.036
# 62            drivers_channel_satisfaction_score                     Similac Pro-Total Comfort                      -0.030

# %%
rb_tree.loc[0,['child', 'root', 'emotional_engagement_score']] = ['RB', np.nan,np.nan]

# %%
rb_tree['id'] = list(range(1, rb_tree.shape[0]+1))

# %%
rb_tree
# Out:
#                                            child                                          root  emotional_engagement_score  id
# 0                                             RB                                           NaN                         NaN   1
# 1                                      RB Health                                            RB                       0.181   2
# 2                                         Danone                                            RB                       0.190   3
# 3                                         Abbott                                            RB                       0.228   4
# 4                                     Nutramigen                                     RB Health                       0.153   5
# 5                                           Enfa                                     RB Health                       0.182   6
# 6                                        Neocate                                        Danone                      -0.494   7
# 7                                   Happy Brands                                        Danone                       0.229   8
# 8                                    Abbott Grow                                        Abbott                      -0.766   9
# 9                                        Elecare                                        Abbott                      -0.303  10
# 10                                       Similac                                        Abbott                       0.151  11
# 11                                 Nutramigen HA                                    Nutramigen                       0.039  12
# 12                                    Nutramigen                                    Nutramigen                       0.211  13
# 13                           Nutramigen Puramino                                    Nutramigen                       0.613  14
# 14  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                                          Enfa                      -1.220  15
# 15                                Nutramigen Lgg                                          Enfa                      -0.797  16
# 16                              Enfamil Prosobee                                          Enfa                      -0.572  17
# 17                                       NEOCATE                                       Neocate                      -0.494  18
# 18                                    Happy Baby                                  Happy Brands                       0.229  19
# 19                                          Grow                                   Abbott Grow                      -0.766  20
# 20                                       Elecare                                       Elecare                      -0.303  21
# 21                                  Similac 2-Fl                                       Similac                      -0.903  22
# 22                           Similac For Spit Up                                       Similac                      -0.780  23
# 23                     Similac Pro-Total Comfort                                       Similac                      -0.395  24
# 24                        drivers_fairness_score                                 Nutramigen HA                      -0.012  25
# 25                       drivers_freshness_score                                 Nutramigen HA                      -0.010  26
# 26                  drivers_ease_of_access_score                                 Nutramigen HA                       0.000  27
# 27                       drivers_packaging_score                                    Nutramigen                      -0.026  28
# 28                      drivers_timeliness_score                                    Nutramigen                      -0.002  29
# 29                  drivers_ease_of_access_score                                    Nutramigen                       0.000  30
# 30                    drivers_waiting_time_score                           Nutramigen Puramino                       0.000  31
# 31                         drivers_respect_score                           Nutramigen Puramino                       0.000  32
# 32                   drivers_future_issues_score                           Nutramigen Puramino                       0.000  33
# 33                       drivers_freshness_score  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                      -0.460  34
# 34                      drivers_well_being_score  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                      -0.107  35
# 35                      drivers_positivity_score  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                      -0.061  36
# 36                       drivers_freshness_score                                Nutramigen Lgg                      -0.126  37
# 37                            drivers_care_score                                Nutramigen Lgg                      -0.028  38
# 38                         drivers_outcome_score                                Nutramigen Lgg                      -0.011  39
# 39                           drivers_trust_score                              Enfamil Prosobee                      -0.079  40
# 40                     drivers_convenience_score                              Enfamil Prosobee                      -0.061  41
# 41                        drivers_fairness_score                              Enfamil Prosobee                      -0.038  42
# 42            drivers_channel_satisfaction_score                                       NEOCATE                      -0.040  43
# 43                       drivers_packaging_score                                       NEOCATE                      -0.030  44
# 44                        drivers_fairness_score                                       NEOCATE                      -0.023  45
# 45                        drivers_fairness_score                                    Happy Baby                      -0.002  46
# 46                           drivers_trust_score                                    Happy Baby                      -0.002  47
# 47            drivers_channel_satisfaction_score                                    Happy Baby                      -0.000  48
# 48                       drivers_freshness_score                                          Grow                      -0.049  49
# 49                            drivers_care_score                                          Grow                      -0.026  50
# 50                      drivers_positivity_score                                          Grow                      -0.023  51
# 51                       drivers_freshness_score                                       Elecare                      -0.113  52
# 52                            drivers_care_score                                       Elecare                      -0.042  53
# 53                        drivers_fairness_score                                       Elecare                      -0.029  54
# 54                       drivers_freshness_score                                  Similac 2-Fl                      -0.381  55
# 55            drivers_channel_satisfaction_score                                  Similac 2-Fl                      -0.052  56
# 56                         drivers_outcome_score                                  Similac 2-Fl                      -0.014  57
# 57                      drivers_well_being_score                           Similac For Spit Up                      -0.336  58
# 58                      drivers_positivity_score                           Similac For Spit Up                      -0.119  59
# 59                         drivers_outcome_score                           Similac For Spit Up                      -0.076  60
# 60                       drivers_freshness_score                     Similac Pro-Total Comfort                      -0.087  61
# 61                       drivers_packaging_score                     Similac Pro-Total Comfort                      -0.036  62
# 62            drivers_channel_satisfaction_score                     Similac Pro-Total Comfort                      -0.030  63

# %%
rb_tree.rename(columns= {'root':'parent_id', 'child':'name'}, inplace = True)

# %%
rb_tree['id'] = rb_tree['name']

# %%
rb_tree
# Out:
#                                             name                                     parent_id  emotional_engagement_score                                            id
# 0                                             RB                                           NaN                         NaN                                            RB
# 1                                      RB Health                                            RB                       0.181                                     RB Health
# 2                                         Danone                                            RB                       0.190                                        Danone
# 3                                         Abbott                                            RB                       0.228                                        Abbott
# 4                                     Nutramigen                                     RB Health                       0.153                                    Nutramigen
# 5                                           Enfa                                     RB Health                       0.182                                          Enfa
# 6                                        Neocate                                        Danone                      -0.494                                       Neocate
# 7                                   Happy Brands                                        Danone                       0.229                                  Happy Brands
# 8                                    Abbott Grow                                        Abbott                      -0.766                                   Abbott Grow
# 9                                        Elecare                                        Abbott                      -0.303                                       Elecare
# 10                                       Similac                                        Abbott                       0.151                                       Similac
# 11                                 Nutramigen HA                                    Nutramigen                       0.039                                 Nutramigen HA
# 12                                    Nutramigen                                    Nutramigen                       0.211                                    Nutramigen
# 13                           Nutramigen Puramino                                    Nutramigen                       0.613                           Nutramigen Puramino
# 14  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                                          Enfa                      -1.220  Enfamil D-Vi-Sol Liquid Vitamin D Supplement
# 15                                Nutramigen Lgg                                          Enfa                      -0.797                                Nutramigen Lgg
# 16                              Enfamil Prosobee                                          Enfa                      -0.572                              Enfamil Prosobee
# 17                                       NEOCATE                                       Neocate                      -0.494                                       NEOCATE
# 18                                    Happy Baby                                  Happy Brands                       0.229                                    Happy Baby
# 19                                          Grow                                   Abbott Grow                      -0.766                                          Grow
# 20                                       Elecare                                       Elecare                      -0.303                                       Elecare
# 21                                  Similac 2-Fl                                       Similac                      -0.903                                  Similac 2-Fl
# 22                           Similac For Spit Up                                       Similac                      -0.780                           Similac For Spit Up
# 23                     Similac Pro-Total Comfort                                       Similac                      -0.395                     Similac Pro-Total Comfort
# 24                        drivers_fairness_score                                 Nutramigen HA                      -0.012                        drivers_fairness_score
# 25                       drivers_freshness_score                                 Nutramigen HA                      -0.010                       drivers_freshness_score
# 26                  drivers_ease_of_access_score                                 Nutramigen HA                       0.000                  drivers_ease_of_access_score
# 27                       drivers_packaging_score                                    Nutramigen                      -0.026                       drivers_packaging_score
# 28                      drivers_timeliness_score                                    Nutramigen                      -0.002                      drivers_timeliness_score
# 29                  drivers_ease_of_access_score                                    Nutramigen                       0.000                  drivers_ease_of_access_score
# 30                    drivers_waiting_time_score                           Nutramigen Puramino                       0.000                    drivers_waiting_time_score
# 31                         drivers_respect_score                           Nutramigen Puramino                       0.000                         drivers_respect_score
# 32                   drivers_future_issues_score                           Nutramigen Puramino                       0.000                   drivers_future_issues_score
# 33                       drivers_freshness_score  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                      -0.460                       drivers_freshness_score
# 34                      drivers_well_being_score  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                      -0.107                      drivers_well_being_score
# 35                      drivers_positivity_score  Enfamil D-Vi-Sol Liquid Vitamin D Supplement                      -0.061                      drivers_positivity_score
# 36                       drivers_freshness_score                                Nutramigen Lgg                      -0.126                       drivers_freshness_score
# 37                            drivers_care_score                                Nutramigen Lgg                      -0.028                            drivers_care_score
# 38                         drivers_outcome_score                                Nutramigen Lgg                      -0.011                         drivers_outcome_score
# 39                           drivers_trust_score                              Enfamil Prosobee                      -0.079                           drivers_trust_score
# 40                     drivers_convenience_score                              Enfamil Prosobee                      -0.061                     drivers_convenience_score
# 41                        drivers_fairness_score                              Enfamil Prosobee                      -0.038                        drivers_fairness_score
# 42            drivers_channel_satisfaction_score                                       NEOCATE                      -0.040            drivers_channel_satisfaction_score
# 43                       drivers_packaging_score                                       NEOCATE                      -0.030                       drivers_packaging_score
# 44                        drivers_fairness_score                                       NEOCATE                      -0.023                        drivers_fairness_score
# 45                        drivers_fairness_score                                    Happy Baby                      -0.002                        drivers_fairness_score
# 46                           drivers_trust_score                                    Happy Baby                      -0.002                           drivers_trust_score
# 47            drivers_channel_satisfaction_score                                    Happy Baby                      -0.000            drivers_channel_satisfaction_score
# 48                       drivers_freshness_score                                          Grow                      -0.049                       drivers_freshness_score
# 49                            drivers_care_score                                          Grow                      -0.026                            drivers_care_score
# 50                      drivers_positivity_score                                          Grow                      -0.023                      drivers_positivity_score
# 51                       drivers_freshness_score                                       Elecare                      -0.113                       drivers_freshness_score
# 52                            drivers_care_score                                       Elecare                      -0.042                            drivers_care_score
# 53                        drivers_fairness_score                                       Elecare                      -0.029                        drivers_fairness_score
# 54                       drivers_freshness_score                                  Similac 2-Fl                      -0.381                       drivers_freshness_score
# 55            drivers_channel_satisfaction_score                                  Similac 2-Fl                      -0.052            drivers_channel_satisfaction_score
# 56                         drivers_outcome_score                                  Similac 2-Fl                      -0.014                         drivers_outcome_score
# 57                      drivers_well_being_score                           Similac For Spit Up                      -0.336                      drivers_well_being_score
# 58                      drivers_positivity_score                           Similac For Spit Up                      -0.119                      drivers_positivity_score
# 59                         drivers_outcome_score                           Similac For Spit Up                      -0.076                         drivers_outcome_score
# 60                       drivers_freshness_score                     Similac Pro-Total Comfort                      -0.087                       drivers_freshness_score
# 61                       drivers_packaging_score                     Similac Pro-Total Comfort                      -0.036                       drivers_packaging_score
# 62            drivers_channel_satisfaction_score                     Similac Pro-Total Comfort                      -0.030            drivers_channel_satisfaction_score

# %%
connection = pg.connect('postgresql://aidatabases:Aidatabases#@65.1.96.15:5432/pathos_db')
engine = create_engine('postgresql://aidatabases:Aidatabases#@65.1.96.15:5432/pathos_db')

# %%
push_table_pgres(rb_tree, df_name = 'rb_tree_june', schema= 'pathos_rb_schema')

# %%
sql_schema='''ALTER TABLE pathos_rb_schema.rb_tree_june
ALTER COLUMN id TYPE text,
ALTER COLUMN root TYPE text,
ALTER COLUMN child TYPE text
'''
engine.execute(sql_schema)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python38\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#
# ~\AppData\Roaming\Python\Python38\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     607     def do_execute(self, cursor, statement, parameters, context=None):
# --> 608         cursor.execute(statement, parameters)
#     609
#
# UndefinedColumn: column "root" of relation "rb_tree_june" does not exist
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-39-616e01b50f67> in <module>
#       4 ALTER COLUMN child TYPE text
#       5 '''
# ----> 6 engine.execute(sql_schema)
#
# ~\AppData\Roaming\Python\Python38\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2233
#    2234         connection = self._contextual_connect(close_with_result=True)
# -> 2235         return connection.execute(statement, *multiparams, **params)
#    2236
#    2237     def scalar(self, statement, *multiparams, **params):
#
# ~\AppData\Roaming\Python\Python38\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1001         """
#    1002         if isinstance(object_, util.string_types[0]):
# -> 1003             return self._execute_text(object_, multiparams, params)
#    1004         try:
#    1005             meth = object_._execute_on_connection
#
# ~\AppData\Roaming\Python\Python38\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1170         dialect = self.dialect
#    1171         parameters = _distill_params(multiparams, params)
# -> 1172         ret = self._execute_context(
#    1173             dialect,
#    1174             dialect.execution_ctx_cls._init_statement,
#
# ~\AppData\Roaming\Python\Python38\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\AppData\Roaming\Python\Python38\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\AppData\Roaming\Python\Python38\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\AppData\Roaming\Python\Python38\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1274                             break
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#    1278                     )
#
# ~\AppData\Roaming\Python\Python38\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     606
#     607     def do_execute(self, cursor, statement, parameters, context=None):
# --> 608         cursor.execute(statement, parameters)
#     609
#     610     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "root" of relation "rb_tree_june" does not exist
#
# [SQL: ALTER TABLE pathos_rb_schema.rb_tree_june
# ALTER COLUMN id TYPE text,
# ALTER COLUMN root TYPE text,
# ALTER COLUMN child TYPE text
# ]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
rb_tree
# Out:
#                                             name     parent_id  emotional_engagement_score                                            id
# 0                                             RB           NaN                         NaN                                            RB
# 1                                      RB Health            RB                       0.181                                     RB Health
# 2                                         Danone            RB                       0.190                                        Danone
# 3                                         Abbott            RB                       0.228                                        Abbott
# 4                                     Nutramigen     RB Health                       0.153                                    Nutramigen
# 5                                           Enfa     RB Health                       0.182                                          Enfa
# 6                                        Neocate        Danone                      -0.494                                       Neocate
# 7                                   Happy Brands        Danone                       0.229                                  Happy Brands
# 8                                    Abbott Grow        Abbott                      -0.766                                   Abbott Grow
# 9                                        Elecare        Abbott                      -0.303                                       Elecare
# 10                                       Similac        Abbott                       0.151                                       Similac
# 11                                 Nutramigen HA    Nutramigen                       0.039                                 Nutramigen HA
# 12                                    Nutramigen    Nutramigen                       0.211                                    Nutramigen
# 13                           Nutramigen Puramino    Nutramigen                       0.613                           Nutramigen Puramino
# 14  Enfamil D-Vi-Sol Liquid Vitamin D Supplement          Enfa                      -1.220  Enfamil D-Vi-Sol Liquid Vitamin D Supplement
# 15                                Nutramigen Lgg          Enfa                      -0.797                                Nutramigen Lgg
# 16                              Enfamil Prosobee          Enfa                      -0.572                              Enfamil Prosobee
# 17                                       NEOCATE       Neocate                      -0.494                                       NEOCATE
# 18                                    Happy Baby  Happy Brands                       0.229                                    Happy Baby
# 19                                          Grow   Abbott Grow                      -0.766                                          Grow
# 20                                       Elecare       Elecare                      -0.303                                       Elecare
# 21                                  Similac 2-Fl       Similac                      -0.903                                  Similac 2-Fl
# 22                           Similac For Spit Up       Similac                      -0.780                           Similac For Spit Up
# 23                     Similac Pro-Total Comfort       Similac                      -0.395                     Similac Pro-Total Comfort
