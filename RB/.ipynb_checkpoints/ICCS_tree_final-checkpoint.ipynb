# %%
from pathos_config import *

summary_table = load_data('iccs_summary_table', 'pathos_iccs_schema', connection)

# %%
# summary_table_manufacturer = summary_table.groupby(['manufacturer']).emotional_engagement_score.mean().sort_values().head(3)
# summary_table_manufacturer = summary_table_manufacturer.to_frame().reset_index()
# manufacturer_list = list(summary_table_manufacturer['manufacturer'])

# %%
# column_list = ['manufacturer', 'brand', 'product', 'emotional_engagement_score']

# %%
# df_brand = pd.DataFrame(columns=['manufacturer', 'brand', 'emotional_engagement_score'])
# for i in range(len(manufacturer_list)):
#     sample_var_manufacturer = manufacturer_list[i]
#     #print(sample_var_manufacturer)
#     vars()[sample_var_manufacturer] = summary_table.loc[summary_table['manufacturer']==sample_var_manufacturer]
#     vars()[sample_var_manufacturer] = vars()[sample_var_manufacturer][column_list]
#     df_manufacturer_brand = vars()[sample_var_manufacturer].groupby(['brand']).emotional_engagement_score.mean().sort_values().head(3)
#     df_manufacturer_brand = df_manufacturer_brand.to_frame().reset_index()
#     brand_list = list(df_manufacturer_brand['brand'])
#     #print(df_manufacturer_brand)
#     df_manufacturer_brand['manufacturer'] = sample_var_manufacturer
#     df_brand = df_brand.append(df_manufacturer_brand, ignore_index = True)  
#     return df_brand

# %%
rb_tree = pd.DataFrame()

# %%
rb_tree.loc[0,['id','name', 'parent_id', 'emotional_engagement_score']] = ['ICCS','ICCS', np.nan,np.nan]

# %%
rb_tree
# Out:
#      id  name  parent_id  emotional_engagement_score
# 0  ICCS  ICCS        NaN                         NaN

# %%
df_level1 = summary_table.groupby(['location']).emotional_engagement_score.mean().sort_values().head(3)
df_level1 = df_level1.to_frame().reset_index()

# %%
df_level1['parent_id']= rb_tree['id'][0]

# %%
df_level1.rename(columns={'location':'name'}, inplace=True)

# %%
df_level1['id'] = df_level1['parent_id'] +"_"+ df_level1['name']

# %%
df_level1
# Out:
#        name  emotional_engagement_score parent_id             id
# 0   Ontario                      -0.453      ICCS   ICCS_Ontario
# 1  Manitoba                      -0.413      ICCS  ICCS_Manitoba
# 2      Peel                      -0.392      ICCS      ICCS_Peel

# %%
def filter_aggregator_level2(level1, level2, dataframe, previous_level):
    column_list = ['location', 'occupation', 'age', 'emotional_engagement_score']
    summary_table_level1 = dataframe.groupby([level1]).emotional_engagement_score.mean().sort_values().head(3)
    summary_table_level1 = summary_table_level1.to_frame().reset_index()
    level1_list = list(summary_table_level1[level1])
    df_level2 = pd.DataFrame(columns=[level1, level2, 'emotional_engagement_score'])
    for i in range(len(level1_list)):
        sample_var_level1 = level1_list[i]
        #print(sample_var_manufacturer)
        vars()[sample_var_level1] = dataframe.loc[dataframe[level1]==sample_var_level1]
        vars()[sample_var_level1] = vars()[sample_var_level1][column_list]
        df_level1_level2 = vars()[sample_var_level1].groupby([level2]).emotional_engagement_score.mean().sort_values().head(3)
        df_level1_level2 = df_level1_level2.to_frame().reset_index()
        level2_list = list(df_level1_level2[level2])
        #print(df_manufacturer_brand)
        df_level1_level2[level1] = sample_var_level1
        print(df_level1_level2[level1])
        #df_level1_level2['id'] = previous_level['parent_id'] + "_" +sample_var_level1
        df_level2 = df_level2.append(df_level1_level2, ignore_index = True)  
    return df_level2

# %%
df_level2 = filter_aggregator_level2(level1='location', level2='occupation', previous_level= df_level1, dataframe=summary_table)
# Out:
# 0    Ontario
# 1    Ontario
# 2    Ontario
# Name: location, dtype: object
# 0    Manitoba
# 1    Manitoba
# 2    Manitoba
# Name: location, dtype: object
# 0    Peel
# 1    Peel
# 2    Peel
# Name: location, dtype: object

# %%
df_level2.rename(columns={'location':'parent_id', 'occupation':'name'}, inplace=True)

# %%
df_level2
# Out:
#   parent_id                                     name  emotional_engagement_score             id
# 0   Ontario                     Prefer not to answer                      -0.581   ICCS_Ontario
# 1   Ontario               Student, full or part time                      -0.572   ICCS_Ontario
# 2   Ontario  Paid employment, part time or full time                      -0.559   ICCS_Ontario
# 3  Manitoba                     Prefer not to answer                      -0.829  ICCS_Manitoba
# 4  Manitoba  Paid employment, part time or full time                      -0.487  ICCS_Manitoba
# 5  Manitoba                                  Retired                      -0.483  ICCS_Manitoba
# 6      Peel                     Prefer not to answer                      -0.966      ICCS_Peel
# 7      Peel                                    Other                      -0.592      ICCS_Peel
# 8      Peel               Student, full or part time                      -0.576      ICCS_Peel

# %%
def filter_aggregator_level3(level1, level2,level3, dataframe): 
    column_list = ['location', 'occupation', 'age', 'emotional_engagement_score']
    summary_table_level1 = dataframe.groupby([level1]).emotional_engagement_score.mean().sort_values().head(3)
    summary_table_level1 = summary_table_level1.to_frame().reset_index()
    level1_list = list(summary_table_level1[level1])
    df_level3 = pd.DataFrame(columns=[level1, level2, level3,'emotional_engagement_score'])
    level_list = []
    for i in range(len(level1_list)):
        sample_var_level1 = level1_list[i]
        print(sample_var_level1)
        vars()[sample_var_level1] = dataframe.loc[dataframe[level1]==sample_var_level1]
        vars()[sample_var_level1] = vars()[sample_var_level1][column_list]
        df_level1_level2 = vars()[sample_var_level1].groupby([level2]).emotional_engagement_score.mean().sort_values().head(3)
        df_level1_level2 = df_level1_level2.to_frame().reset_index()
        level2_list = list(df_level1_level2[level2])
        #df_level1_level2[level1] = sample_var_level1
        #level_list.append(level2_list)
        
        for i in range(len(level2_list)):
            sample_var_level2 = level2_list[i]
            print(sample_var_level2)
            vars()[sample_var_level2] = dataframe.loc[dataframe[level2]==sample_var_level2]
            vars()[sample_var_level2] = vars()[sample_var_level2][column_list]
            df_level2_level3 = vars()[sample_var_level2].groupby([level3]).emotional_engagement_score.mean().sort_values().head(3)
            df_level2_level3 = df_level2_level3.to_frame().reset_index()
            level3_list = list(df_level2_level3[level3])
            df_level2_level3[level1] = sample_var_level1
            df_level2_level3[level2] = sample_var_level2
            df_level3 = df_level3.append(df_level2_level3, ignore_index = True) 
    return df_level3

# %%
df_level3 = filter_aggregator_level3(level1='location', level2='occupation',level3 = 'age', dataframe=summary_table)
# Out:
# Ontario
# Prefer not to answer
# Student, full or part time
# Paid employment, part time or full time
# Manitoba
# Prefer not to answer
# Paid employment, part time or full time
# Retired
# Peel
# Prefer not to answer
# Other
# Student, full or part time

# %%
df_level3['id'] = df_level3.groupby(['occupation']).ngroup()

# %%
df_level3['id'] = df_level3['id'].apply(str)

# %%
df_level3['occupation'] = df_level3['location'] + df_level3['id']

# %%
df_level3.drop(columns={'location', 'id'}, inplace=True)

# %%
df_level3.rename(columns={'occupation':'root', 'age':'child'}, inplace=True)

# %%
def filter_aggregator_drivers(level1, level2,level3, dataframe): 
    column_list = ['location', 'occupation', 'age', 'emotional_engagement_score']
    drivers_list = ['drivers_personalization_score', 'drivers_positivity_score', 'drivers_well_being_score', 'drivers_exciting_score', 'drivers_belonging_score', 'drivers_sustainability_score', 'drivers_security_score', 'drivers_convenience_score',
       'drivers_care_score', 'drivers_timeliness_score', 'drivers_respect_score', 'drivers_knowledge_score', 'drivers_fairness_score', 'drivers_channel_satisfaction_score', 'drivers_outcome_score', 'drivers_communication_score', 'drivers_ease_of_access_score', 'drivers_future_issues_score', 'drivers_competence_score', 'drivers_extra_mile_score', 'drivers_waiting_time_score', 'drivers_appeal_score', 'drivers_preferred_chanel_score', 'drivers_freshness_score', 'drivers_trust_score', 'drivers_regret_score', 'drivers_relationship_score', 'drivers_innovative_score', 'drivers_value_for_money_score', 'drivers_packaging_score']
    added_driver_list = column_list + drivers_list
    summary_table_level1 = dataframe.groupby([level1]).emotional_engagement_score.mean().sort_values().head(3)
    summary_table_level1 = summary_table_level1.to_frame().reset_index()
    level1_list = list(summary_table_level1[level1])
    df_level4 = pd.DataFrame(columns=[level1, level2, level3,'emotional_engagement_score'])
    level_list = []
    for i in range(len(level1_list)):
        sample_var_level1 = level1_list[i]
        print(sample_var_level1)
        vars()[sample_var_level1] = dataframe.loc[dataframe[level1]==sample_var_level1]
        vars()[sample_var_level1] = vars()[sample_var_level1][added_driver_list]
        df_level1_level2 = vars()[sample_var_level1].groupby([level2]).emotional_engagement_score.mean().sort_values().head(3)
        df_level1_level2 = df_level1_level2.to_frame().reset_index()
        level2_list = list(df_level1_level2[level2])
        #df_level1_level2[level1] = sample_var_level1
        #level_list.append(level2_list)
        
        for i in range(len(level2_list)):
            sample_var_level2 = level2_list[i]
            #print(sample_var_level2)
            vars()[sample_var_level2] = dataframe.loc[dataframe[level2]==sample_var_level2]
            vars()[sample_var_level2] = vars()[sample_var_level2][added_driver_list]
            df_level2_level3 = vars()[sample_var_level2].groupby([level3]).emotional_engagement_score.mean().sort_values().head(3)
            df_level2_level3 = df_level2_level3.to_frame().reset_index()
            level3_list = list(df_level2_level3[level3])
#             df_level2_level3[level1] = sample_var_level1
#             df_level2_level3[level2] = sample_var_level2
#             df_level3 = df_level3.append(df_level2_level3, ignore_index = True)
            for i in range(len(level3_list)):
                sample_var_level3= level3_list[i]
                #print(sample_var_level3)
                vars()[sample_var_level3] = dataframe.loc[dataframe[level3]==sample_var_level3]
                vars()[sample_var_level3] = vars()[sample_var_level3][added_driver_list]
                
                vars()[sample_var_level3].dropna(axis=1, how='all', inplace=True)
                common_drivers = list(set(drivers_list).intersection(vars()[sample_var_level3].columns))
                vars()[sample_var_level3]= vars()[sample_var_level3][common_drivers].mean().sort_values().head(3)
                df_level3_level4 = vars()[sample_var_level3].to_frame().reset_index()
                df_level3_level4.reset_index(inplace=True)
                df_level3_level4[level3] = sample_var_level3
                df_level4 = df_level4.append(df_level3_level4, ignore_index = True)
                
                
                #print(df_level3_level4)

            
    return df_level4

# %%
df_level4 = filter_aggregator_drivers(level1='location', level2='occupation',level3 = 'age', dataframe=summary_table)
# Out:
# Ontario
# Manitoba
# Peel

# %%
df_level4
# Out:
#    location occupation          age emotional_engagement_score  level_0                        index      0  id
# 0       NaN        NaN  25-34 years                        NaN    0.000   drivers_waiting_time_score -0.336   1
# 1       NaN        NaN  25-34 years                        NaN    1.000     drivers_timeliness_score -0.163   1
# 2       NaN        NaN  25-34 years                        NaN    2.000  drivers_communication_score -0.123   1
# 3       NaN        NaN  45-54 years                        NaN    0.000   drivers_waiting_time_score -0.354   3
# 4       NaN        NaN  45-54 years                        NaN    1.000     drivers_timeliness_score -0.135   3
# 5       NaN        NaN  45-54 years                        NaN    2.000  drivers_communication_score -0.106   3
# 6       NaN        NaN    75+ years                        NaN    0.000           drivers_care_score -0.677   5
# 7       NaN        NaN    75+ years                        NaN    1.000        drivers_outcome_score -0.022   5
# 8       NaN        NaN    75+ years                        NaN    2.000     drivers_positivity_score -0.007   5
# 9       NaN        NaN  45-54 years                        NaN    0.000   drivers_waiting_time_score -0.354   3
# 10      NaN        NaN  45-54 years                        NaN    1.000     drivers_timeliness_score -0.135   3
# 11      NaN        NaN  45-54 years                        NaN    2.000  drivers_communication_score -0.106   3
# 12      NaN        NaN  18-24 years                        NaN    0.000   drivers_waiting_time_score -0.483   0
# 13      NaN        NaN  18-24 years                        NaN    1.000     drivers_timeliness_score -0.184   0
# 14      NaN        NaN  18-24 years                        NaN    2.000  drivers_communication_score -0.090   0
# 15      NaN        NaN  35-44 years                        NaN    0.000   drivers_waiting_time_score -0.350   2
# 16      NaN        NaN  35-44 years                        NaN    1.000     drivers_timeliness_score -0.183   2
# 17      NaN        NaN  35-44 years                        NaN    2.000  drivers_communication_score -0.115   2
# 18      NaN        NaN  18-24 years                        NaN    0.000   drivers_waiting_time_score -0.483   0
# 19      NaN        NaN  18-24 years                        NaN    1.000     drivers_timeliness_score -0.184   0
# 20      NaN        NaN  18-24 years                        NaN    2.000  drivers_communication_score -0.090   0
# 21      NaN        NaN  55-64 years                        NaN    0.000   drivers_waiting_time_score -0.349   4
# 22      NaN        NaN  55-64 years                        NaN    1.000     drivers_timeliness_score -0.154   4
# 23      NaN        NaN  55-64 years                        NaN    2.000  drivers_communication_score -0.100   4
# 24      NaN        NaN  35-44 years                        NaN    0.000   drivers_waiting_time_score -0.350   2
# 25      NaN        NaN  35-44 years                        NaN    1.000     drivers_timeliness_score -0.183   2
# 26      NaN        NaN  35-44 years                        NaN    2.000  drivers_communication_score -0.115   2
# 27      NaN        NaN  25-34 years                        NaN    0.000   drivers_waiting_time_score -0.336   1
# 28      NaN        NaN  25-34 years                        NaN    1.000     drivers_timeliness_score -0.163   1
# 29      NaN        NaN  25-34 years                        NaN    2.000  drivers_communication_score -0.123   1
# 30      NaN        NaN  45-54 years                        NaN    0.000   drivers_waiting_time_score -0.354   3
# 31      NaN        NaN  45-54 years                        NaN    1.000     drivers_timeliness_score -0.135   3
# 32      NaN        NaN  45-54 years                        NaN    2.000  drivers_communication_score -0.106   3
# 33      NaN        NaN    75+ years                        NaN    0.000           drivers_care_score -0.677   5
# 34      NaN        NaN    75+ years                        NaN    1.000        drivers_outcome_score -0.022   5
# 35      NaN        NaN    75+ years                        NaN    2.000     drivers_positivity_score -0.007   5
# 36      NaN        NaN  18-24 years                        NaN    0.000   drivers_waiting_time_score -0.483   0
# 37      NaN        NaN  18-24 years                        NaN    1.000     drivers_timeliness_score -0.184   0
# 38      NaN        NaN  18-24 years                        NaN    2.000  drivers_communication_score -0.090   0
# 39      NaN        NaN  55-64 years                        NaN    0.000   drivers_waiting_time_score -0.349   4
# 40      NaN        NaN  55-64 years                        NaN    1.000     drivers_timeliness_score -0.154   4
# 41      NaN        NaN  55-64 years                        NaN    2.000  drivers_communication_score -0.100   4
# 42      NaN        NaN  35-44 years                        NaN    0.000   drivers_waiting_time_score -0.350   2
# 43      NaN        NaN  35-44 years                        NaN    1.000     drivers_timeliness_score -0.183   2
# 44      NaN        NaN  35-44 years                        NaN    2.000  drivers_communication_score -0.115   2
# 45      NaN        NaN  35-44 years                        NaN    0.000   drivers_waiting_time_score -0.350   2
# 46      NaN        NaN  35-44 years                        NaN    1.000     drivers_timeliness_score -0.183   2
# 47      NaN        NaN  35-44 years                        NaN    2.000  drivers_communication_score -0.115   2
# 48      NaN        NaN  45-54 years                        NaN    0.000   drivers_waiting_time_score -0.354   3
# 49      NaN        NaN  45-54 years                        NaN    1.000     drivers_timeliness_score -0.135   3
# 50      NaN        NaN  45-54 years                        NaN    2.000  drivers_communication_score -0.106   3
# 51      NaN        NaN  55-64 years                        NaN    0.000   drivers_waiting_time_score -0.349   4
# 52      NaN        NaN  55-64 years                        NaN    1.000     drivers_timeliness_score -0.154   4
# 53      NaN        NaN  55-64 years                        NaN    2.000  drivers_communication_score -0.100   4
# 54      NaN        NaN  25-34 years                        NaN    0.000   drivers_waiting_time_score -0.336   1
# 55      NaN        NaN  25-34 years                        NaN    1.000     drivers_timeliness_score -0.163   1
# 56      NaN        NaN  25-34 years                        NaN    2.000  drivers_communication_score -0.123   1
# 57      NaN        NaN  45-54 years                        NaN    0.000   drivers_waiting_time_score -0.354   3
# 58      NaN        NaN  45-54 years                        NaN    1.000     drivers_timeliness_score -0.135   3
# 59      NaN        NaN  45-54 years                        NaN    2.000  drivers_communication_score -0.106   3
# 60      NaN        NaN    75+ years                        NaN    0.000           drivers_care_score -0.677   5
# 61      NaN        NaN    75+ years                        NaN    1.000        drivers_outcome_score -0.022   5
# 62      NaN        NaN    75+ years                        NaN    2.000     drivers_positivity_score -0.007   5
# 63      NaN        NaN  18-24 years                        NaN    0.000   drivers_waiting_time_score -0.483   0
# 64      NaN        NaN  18-24 years                        NaN    1.000     drivers_timeliness_score -0.184   0
# 65      NaN        NaN  18-24 years                        NaN    2.000  drivers_communication_score -0.090   0
# 66      NaN        NaN  55-64 years                        NaN    0.000   drivers_waiting_time_score -0.349   4
# 67      NaN        NaN  55-64 years                        NaN    1.000     drivers_timeliness_score -0.154   4
# 68      NaN        NaN  55-64 years                        NaN    2.000  drivers_communication_score -0.100   4
# 69      NaN        NaN  25-34 years                        NaN    0.000   drivers_waiting_time_score -0.336   1
# 70      NaN        NaN  25-34 years                        NaN    1.000     drivers_timeliness_score -0.163   1
# 71      NaN        NaN  25-34 years                        NaN    2.000  drivers_communication_score -0.123   1
# 72      NaN        NaN  45-54 years                        NaN    0.000   drivers_waiting_time_score -0.354   3
# 73      NaN        NaN  45-54 years                        NaN    1.000     drivers_timeliness_score -0.135   3
# 74      NaN        NaN  45-54 years                        NaN    2.000  drivers_communication_score -0.106   3
# 75      NaN        NaN  18-24 years                        NaN    0.000   drivers_waiting_time_score -0.483   0
# 76      NaN        NaN  18-24 years                        NaN    1.000     drivers_timeliness_score -0.184   0
# 77      NaN        NaN  18-24 years                        NaN    2.000  drivers_communication_score -0.090   0
# 78      NaN        NaN  35-44 years                        NaN    0.000   drivers_waiting_time_score -0.350   2
# 79      NaN        NaN  35-44 years                        NaN    1.000     drivers_timeliness_score -0.183   2
# 80      NaN        NaN  35-44 years                        NaN    2.000  drivers_communication_score -0.115   2

# %%
df_level4['id'] = df_level4.groupby(['age']).ngroup()

# %%
df_level4['id'] = df_level4['id'].apply(str)

# %%
df_level4['age'] = df_level4['index'] + df_level4['id']

# %%
df_level4.drop(columns={'location', 'occupation', 'emotional_engagement_score', 'level_0', 'id'}, inplace=True)

# %%
df_level4.rename(columns={'age':'root', 'index':'child', 0:'emotional_engagement_score'}, inplace=True)

# %%
df_level4
# Out:
#    root                        child  emotional_engagement_score
# 0   NaN   drivers_waiting_time_score                      -0.336
# 1   NaN     drivers_timeliness_score                      -0.163
# 2   NaN  drivers_communication_score                      -0.123
# 3   NaN   drivers_waiting_time_score                      -0.354
# 4   NaN     drivers_timeliness_score                      -0.135
# 5   NaN  drivers_communication_score                      -0.106
# 6   NaN           drivers_care_score                      -0.677
# 7   NaN        drivers_outcome_score                      -0.022
# 8   NaN     drivers_positivity_score                      -0.007
# 9   NaN   drivers_waiting_time_score                      -0.354
# 10  NaN     drivers_timeliness_score                      -0.135
# 11  NaN  drivers_communication_score                      -0.106
# 12  NaN   drivers_waiting_time_score                      -0.483
# 13  NaN     drivers_timeliness_score                      -0.184
# 14  NaN  drivers_communication_score                      -0.090
# 15  NaN   drivers_waiting_time_score                      -0.350
# 16  NaN     drivers_timeliness_score                      -0.183
# 17  NaN  drivers_communication_score                      -0.115
# 18  NaN   drivers_waiting_time_score                      -0.483
# 19  NaN     drivers_timeliness_score                      -0.184
# 20  NaN  drivers_communication_score                      -0.090
# 21  NaN   drivers_waiting_time_score                      -0.349
# 22  NaN     drivers_timeliness_score                      -0.154
# 23  NaN  drivers_communication_score                      -0.100
# 24  NaN   drivers_waiting_time_score                      -0.350
# 25  NaN     drivers_timeliness_score                      -0.183
# 26  NaN  drivers_communication_score                      -0.115
# 27  NaN   drivers_waiting_time_score                      -0.336
# 28  NaN     drivers_timeliness_score                      -0.163
# 29  NaN  drivers_communication_score                      -0.123
# 30  NaN   drivers_waiting_time_score                      -0.354
# 31  NaN     drivers_timeliness_score                      -0.135
# 32  NaN  drivers_communication_score                      -0.106
# 33  NaN           drivers_care_score                      -0.677
# 34  NaN        drivers_outcome_score                      -0.022
# 35  NaN     drivers_positivity_score                      -0.007
# 36  NaN   drivers_waiting_time_score                      -0.483
# 37  NaN     drivers_timeliness_score                      -0.184
# 38  NaN  drivers_communication_score                      -0.090
# 39  NaN   drivers_waiting_time_score                      -0.349
# 40  NaN     drivers_timeliness_score                      -0.154
# 41  NaN  drivers_communication_score                      -0.100
# 42  NaN   drivers_waiting_time_score                      -0.350
# 43  NaN     drivers_timeliness_score                      -0.183
# 44  NaN  drivers_communication_score                      -0.115
# 45  NaN   drivers_waiting_time_score                      -0.350
# 46  NaN     drivers_timeliness_score                      -0.183
# 47  NaN  drivers_communication_score                      -0.115
# 48  NaN   drivers_waiting_time_score                      -0.354
# 49  NaN     drivers_timeliness_score                      -0.135
# 50  NaN  drivers_communication_score                      -0.106
# 51  NaN   drivers_waiting_time_score                      -0.349
# 52  NaN     drivers_timeliness_score                      -0.154
# 53  NaN  drivers_communication_score                      -0.100
# 54  NaN   drivers_waiting_time_score                      -0.336
# 55  NaN     drivers_timeliness_score                      -0.163
# 56  NaN  drivers_communication_score                      -0.123
# 57  NaN   drivers_waiting_time_score                      -0.354
# 58  NaN     drivers_timeliness_score                      -0.135
# 59  NaN  drivers_communication_score                      -0.106
# 60  NaN           drivers_care_score                      -0.677
# 61  NaN        drivers_outcome_score                      -0.022
# 62  NaN     drivers_positivity_score                      -0.007
# 63  NaN   drivers_waiting_time_score                      -0.483
# 64  NaN     drivers_timeliness_score                      -0.184
# 65  NaN  drivers_communication_score                      -0.090
# 66  NaN   drivers_waiting_time_score                      -0.349
# 67  NaN     drivers_timeliness_score                      -0.154
# 68  NaN  drivers_communication_score                      -0.100
# 69  NaN   drivers_waiting_time_score                      -0.336
# 70  NaN     drivers_timeliness_score                      -0.163
# 71  NaN  drivers_communication_score                      -0.123
# 72  NaN   drivers_waiting_time_score                      -0.354
# 73  NaN     drivers_timeliness_score                      -0.135
# 74  NaN  drivers_communication_score                      -0.106
# 75  NaN   drivers_waiting_time_score                      -0.483
# 76  NaN     drivers_timeliness_score                      -0.184
# 77  NaN  drivers_communication_score                      -0.090
# 78  NaN   drivers_waiting_time_score                      -0.350
# 79  NaN     drivers_timeliness_score                      -0.183
# 80  NaN  drivers_communication_score                      -0.115

# %%
rb_tree = rb_tree.append(df_level1, ignore_index=True)

# %%
rb_tree = rb_tree.append(df_level2, ignore_index=True)

# %%
rb_tree = rb_tree.append(df_level3, ignore_index=True)

# %%
rb_tree = rb_tree.append(df_level4, ignore_index=True)

# %%
rb_tree
# Out:
#                                        child                                     root  emotional_engagement_score
# 0                                       ICCS                                      NaN                         NaN
# 1                                    Ontario                                     ICCS                      -0.453
# 2                                   Manitoba                                     ICCS                      -0.413
# 3                                       Peel                                     ICCS                      -0.392
# 4                       Prefer not to answer                                  Ontario                      -0.581
# 5                 Student, full or part time                                  Ontario                      -0.572
# 6    Paid employment, part time or full time                                  Ontario                      -0.559
# 7                       Prefer not to answer                                 Manitoba                      -0.829
# 8    Paid employment, part time or full time                                 Manitoba                      -0.487
# 9                                    Retired                                 Manitoba                      -0.483
# 10                      Prefer not to answer                                     Peel                      -0.966
# 11                                     Other                                     Peel                      -0.592
# 12                Student, full or part time                                     Peel                      -0.576
# 13                               25-34 years                     Prefer not to answer                      -0.764
# 14                               45-54 years                     Prefer not to answer                      -0.534
# 15                                 75+ years                     Prefer not to answer                      -0.448
# 16                               45-54 years               Student, full or part time                      -0.824
# 17                               18-24 years               Student, full or part time                      -0.420
# 18                               35-44 years               Student, full or part time                      -0.366
# 19                               18-24 years  Paid employment, part time or full time                      -0.448
# 20                               55-64 years  Paid employment, part time or full time                      -0.396
# 21                               35-44 years  Paid employment, part time or full time                      -0.296
# 22                               25-34 years                     Prefer not to answer                      -0.764
# 23                               45-54 years                     Prefer not to answer                      -0.534
# 24                                 75+ years                     Prefer not to answer                      -0.448
# 25                               18-24 years  Paid employment, part time or full time                      -0.448
# 26                               55-64 years  Paid employment, part time or full time                      -0.396
# 27                               35-44 years  Paid employment, part time or full time                      -0.296
# 28                               35-44 years                                  Retired                      -0.769
# 29                               45-54 years                                  Retired                      -0.498
# 30                               55-64 years                                  Retired                      -0.227
# 31                               25-34 years                     Prefer not to answer                      -0.764
# 32                               45-54 years                     Prefer not to answer                      -0.534
# 33                                 75+ years                     Prefer not to answer                      -0.448
# 34                               18-24 years                                    Other                      -0.425
# 35                               55-64 years                                    Other                      -0.377
# 36                               25-34 years                                    Other                      -0.330
# 37                               45-54 years               Student, full or part time                      -0.824
# 38                               18-24 years               Student, full or part time                      -0.420
# 39                               35-44 years               Student, full or part time                      -0.366
# 40                drivers_waiting_time_score                              25-34 years                      -0.336
# 41                  drivers_timeliness_score                              25-34 years                      -0.163
# 42               drivers_communication_score                              25-34 years                      -0.123
# 43                drivers_waiting_time_score                              45-54 years                      -0.354
# 44                  drivers_timeliness_score                              45-54 years                      -0.135
# 45               drivers_communication_score                              45-54 years                      -0.106
# 46                        drivers_care_score                                75+ years                      -0.677
# 47                     drivers_outcome_score                                75+ years                      -0.022
# 48                  drivers_positivity_score                                75+ years                      -0.007
# 49                drivers_waiting_time_score                              45-54 years                      -0.354
# 50                  drivers_timeliness_score                              45-54 years                      -0.135
# 51               drivers_communication_score                              45-54 years                      -0.106
# 52                drivers_waiting_time_score                              18-24 years                      -0.483
# 53                  drivers_timeliness_score                              18-24 years                      -0.184
# 54               drivers_communication_score                              18-24 years                      -0.090
# 55                drivers_waiting_time_score                              35-44 years                      -0.350
# 56                  drivers_timeliness_score                              35-44 years                      -0.183
# 57               drivers_communication_score                              35-44 years                      -0.115
# 58                drivers_waiting_time_score                              18-24 years                      -0.483
# 59                  drivers_timeliness_score                              18-24 years                      -0.184
# 60               drivers_communication_score                              18-24 years                      -0.090
# 61                drivers_waiting_time_score                              55-64 years                      -0.349
# 62                  drivers_timeliness_score                              55-64 years                      -0.154
# 63               drivers_communication_score                              55-64 years                      -0.100
# 64                drivers_waiting_time_score                              35-44 years                      -0.350
# 65                  drivers_timeliness_score                              35-44 years                      -0.183
# 66               drivers_communication_score                              35-44 years                      -0.115
# 67                drivers_waiting_time_score                              25-34 years                      -0.336
# 68                  drivers_timeliness_score                              25-34 years                      -0.163
# 69               drivers_communication_score                              25-34 years                      -0.123
# 70                drivers_waiting_time_score                              45-54 years                      -0.354
# 71                  drivers_timeliness_score                              45-54 years                      -0.135
# 72               drivers_communication_score                              45-54 years                      -0.106
# 73                        drivers_care_score                                75+ years                      -0.677
# 74                     drivers_outcome_score                                75+ years                      -0.022
# 75                  drivers_positivity_score                                75+ years                      -0.007
# 76                drivers_waiting_time_score                              18-24 years                      -0.483
# 77                  drivers_timeliness_score                              18-24 years                      -0.184
# 78               drivers_communication_score                              18-24 years                      -0.090
# 79                drivers_waiting_time_score                              55-64 years                      -0.349
# 80                  drivers_timeliness_score                              55-64 years                      -0.154
# 81               drivers_communication_score                              55-64 years                      -0.100
# 82                drivers_waiting_time_score                              35-44 years                      -0.350
# 83                  drivers_timeliness_score                              35-44 years                      -0.183
# 84               drivers_communication_score                              35-44 years                      -0.115
# 85                drivers_waiting_time_score                              35-44 years                      -0.350
# 86                  drivers_timeliness_score                              35-44 years                      -0.183
# 87               drivers_communication_score                              35-44 years                      -0.115
# 88                drivers_waiting_time_score                              45-54 years                      -0.354
# 89                  drivers_timeliness_score                              45-54 years                      -0.135
# 90               drivers_communication_score                              45-54 years                      -0.106
# 91                drivers_waiting_time_score                              55-64 years                      -0.349
# 92                  drivers_timeliness_score                              55-64 years                      -0.154
# 93               drivers_communication_score                              55-64 years                      -0.100
# 94                drivers_waiting_time_score                              25-34 years                      -0.336
# 95                  drivers_timeliness_score                              25-34 years                      -0.163
# 96               drivers_communication_score                              25-34 years                      -0.123
# 97                drivers_waiting_time_score                              45-54 years                      -0.354
# 98                  drivers_timeliness_score                              45-54 years                      -0.135
# 99               drivers_communication_score                              45-54 years                      -0.106
# 100                       drivers_care_score                                75+ years                      -0.677
# 101                    drivers_outcome_score                                75+ years                      -0.022
# 102                 drivers_positivity_score                                75+ years                      -0.007
# 103               drivers_waiting_time_score                              18-24 years                      -0.483
# 104                 drivers_timeliness_score                              18-24 years                      -0.184
# 105              drivers_communication_score                              18-24 years                      -0.090
# 106               drivers_waiting_time_score                              55-64 years                      -0.349
# 107                 drivers_timeliness_score                              55-64 years                      -0.154
# 108              drivers_communication_score                              55-64 years                      -0.100
# 109               drivers_waiting_time_score                              25-34 years                      -0.336
# 110                 drivers_timeliness_score                              25-34 years                      -0.163
# 111              drivers_communication_score                              25-34 years                      -0.123
# 112               drivers_waiting_time_score                              45-54 years                      -0.354
# 113                 drivers_timeliness_score                              45-54 years                      -0.135
# 114              drivers_communication_score                              45-54 years                      -0.106
# 115               drivers_waiting_time_score                              18-24 years                      -0.483
# 116                 drivers_timeliness_score                              18-24 years                      -0.184
# 117              drivers_communication_score                              18-24 years                      -0.090
# 118               drivers_waiting_time_score                              35-44 years                      -0.350
# 119                 drivers_timeliness_score                              35-44 years                      -0.183
# 120              drivers_communication_score                              35-44 years                      -0.115

# %%
rb_tree.loc[0,['child', 'root', 'emotional_engagement_score']] = ['ICCS', np.nan,np.nan]

# %%
rb_tree['id'] = list(range(1, rb_tree.shape[0]+1))

# %%
rb_tree
# Out:
#                                        child                                     root  emotional_engagement_score   id
# 0                                       ICCS                                      NaN                         NaN    1
# 1                                    Ontario                                     ICCS                      -0.453    2
# 2                                   Manitoba                                     ICCS                      -0.413    3
# 3                                       Peel                                     ICCS                      -0.392    4
# 4                       Prefer not to answer                                  Ontario                      -0.581    5
# 5                 Student, full or part time                                  Ontario                      -0.572    6
# 6    Paid employment, part time or full time                                  Ontario                      -0.559    7
# 7                       Prefer not to answer                                 Manitoba                      -0.829    8
# 8    Paid employment, part time or full time                                 Manitoba                      -0.487    9
# 9                                    Retired                                 Manitoba                      -0.483   10
# 10                      Prefer not to answer                                     Peel                      -0.966   11
# 11                                     Other                                     Peel                      -0.592   12
# 12                Student, full or part time                                     Peel                      -0.576   13
# 13                               25-34 years                     Prefer not to answer                      -0.764   14
# 14                               45-54 years                     Prefer not to answer                      -0.534   15
# 15                                 75+ years                     Prefer not to answer                      -0.448   16
# 16                               45-54 years               Student, full or part time                      -0.824   17
# 17                               18-24 years               Student, full or part time                      -0.420   18
# 18                               35-44 years               Student, full or part time                      -0.366   19
# 19                               18-24 years  Paid employment, part time or full time                      -0.448   20
# 20                               55-64 years  Paid employment, part time or full time                      -0.396   21
# 21                               35-44 years  Paid employment, part time or full time                      -0.296   22
# 22                               25-34 years                     Prefer not to answer                      -0.764   23
# 23                               45-54 years                     Prefer not to answer                      -0.534   24
# 24                                 75+ years                     Prefer not to answer                      -0.448   25
# 25                               18-24 years  Paid employment, part time or full time                      -0.448   26
# 26                               55-64 years  Paid employment, part time or full time                      -0.396   27
# 27                               35-44 years  Paid employment, part time or full time                      -0.296   28
# 28                               35-44 years                                  Retired                      -0.769   29
# 29                               45-54 years                                  Retired                      -0.498   30
# 30                               55-64 years                                  Retired                      -0.227   31
# 31                               25-34 years                     Prefer not to answer                      -0.764   32
# 32                               45-54 years                     Prefer not to answer                      -0.534   33
# 33                                 75+ years                     Prefer not to answer                      -0.448   34
# 34                               18-24 years                                    Other                      -0.425   35
# 35                               55-64 years                                    Other                      -0.377   36
# 36                               25-34 years                                    Other                      -0.330   37
# 37                               45-54 years               Student, full or part time                      -0.824   38
# 38                               18-24 years               Student, full or part time                      -0.420   39
# 39                               35-44 years               Student, full or part time                      -0.366   40
# 40                drivers_waiting_time_score                              25-34 years                      -0.336   41
# 41                  drivers_timeliness_score                              25-34 years                      -0.163   42
# 42               drivers_communication_score                              25-34 years                      -0.123   43
# 43                drivers_waiting_time_score                              45-54 years                      -0.354   44
# 44                  drivers_timeliness_score                              45-54 years                      -0.135   45
# 45               drivers_communication_score                              45-54 years                      -0.106   46
# 46                        drivers_care_score                                75+ years                      -0.677   47
# 47                     drivers_outcome_score                                75+ years                      -0.022   48
# 48                  drivers_positivity_score                                75+ years                      -0.007   49
# 49                drivers_waiting_time_score                              45-54 years                      -0.354   50
# 50                  drivers_timeliness_score                              45-54 years                      -0.135   51
# 51               drivers_communication_score                              45-54 years                      -0.106   52
# 52                drivers_waiting_time_score                              18-24 years                      -0.483   53
# 53                  drivers_timeliness_score                              18-24 years                      -0.184   54
# 54               drivers_communication_score                              18-24 years                      -0.090   55
# 55                drivers_waiting_time_score                              35-44 years                      -0.350   56
# 56                  drivers_timeliness_score                              35-44 years                      -0.183   57
# 57               drivers_communication_score                              35-44 years                      -0.115   58
# 58                drivers_waiting_time_score                              18-24 years                      -0.483   59
# 59                  drivers_timeliness_score                              18-24 years                      -0.184   60
# 60               drivers_communication_score                              18-24 years                      -0.090   61
# 61                drivers_waiting_time_score                              55-64 years                      -0.349   62
# 62                  drivers_timeliness_score                              55-64 years                      -0.154   63
# 63               drivers_communication_score                              55-64 years                      -0.100   64
# 64                drivers_waiting_time_score                              35-44 years                      -0.350   65
# 65                  drivers_timeliness_score                              35-44 years                      -0.183   66
# 66               drivers_communication_score                              35-44 years                      -0.115   67
# 67                drivers_waiting_time_score                              25-34 years                      -0.336   68
# 68                  drivers_timeliness_score                              25-34 years                      -0.163   69
# 69               drivers_communication_score                              25-34 years                      -0.123   70
# 70                drivers_waiting_time_score                              45-54 years                      -0.354   71
# 71                  drivers_timeliness_score                              45-54 years                      -0.135   72
# 72               drivers_communication_score                              45-54 years                      -0.106   73
# 73                        drivers_care_score                                75+ years                      -0.677   74
# 74                     drivers_outcome_score                                75+ years                      -0.022   75
# 75                  drivers_positivity_score                                75+ years                      -0.007   76
# 76                drivers_waiting_time_score                              18-24 years                      -0.483   77
# 77                  drivers_timeliness_score                              18-24 years                      -0.184   78
# 78               drivers_communication_score                              18-24 years                      -0.090   79
# 79                drivers_waiting_time_score                              55-64 years                      -0.349   80
# 80                  drivers_timeliness_score                              55-64 years                      -0.154   81
# 81               drivers_communication_score                              55-64 years                      -0.100   82
# 82                drivers_waiting_time_score                              35-44 years                      -0.350   83
# 83                  drivers_timeliness_score                              35-44 years                      -0.183   84
# 84               drivers_communication_score                              35-44 years                      -0.115   85
# 85                drivers_waiting_time_score                              35-44 years                      -0.350   86
# 86                  drivers_timeliness_score                              35-44 years                      -0.183   87
# 87               drivers_communication_score                              35-44 years                      -0.115   88
# 88                drivers_waiting_time_score                              45-54 years                      -0.354   89
# 89                  drivers_timeliness_score                              45-54 years                      -0.135   90
# 90               drivers_communication_score                              45-54 years                      -0.106   91
# 91                drivers_waiting_time_score                              55-64 years                      -0.349   92
# 92                  drivers_timeliness_score                              55-64 years                      -0.154   93
# 93               drivers_communication_score                              55-64 years                      -0.100   94
# 94                drivers_waiting_time_score                              25-34 years                      -0.336   95
# 95                  drivers_timeliness_score                              25-34 years                      -0.163   96
# 96               drivers_communication_score                              25-34 years                      -0.123   97
# 97                drivers_waiting_time_score                              45-54 years                      -0.354   98
# 98                  drivers_timeliness_score                              45-54 years                      -0.135   99
# 99               drivers_communication_score                              45-54 years                      -0.106  100
# 100                       drivers_care_score                                75+ years                      -0.677  101
# 101                    drivers_outcome_score                                75+ years                      -0.022  102
# 102                 drivers_positivity_score                                75+ years                      -0.007  103
# 103               drivers_waiting_time_score                              18-24 years                      -0.483  104
# 104                 drivers_timeliness_score                              18-24 years                      -0.184  105
# 105              drivers_communication_score                              18-24 years                      -0.090  106
# 106               drivers_waiting_time_score                              55-64 years                      -0.349  107
# 107                 drivers_timeliness_score                              55-64 years                      -0.154  108
# 108              drivers_communication_score                              55-64 years                      -0.100  109
# 109               drivers_waiting_time_score                              25-34 years                      -0.336  110
# 110                 drivers_timeliness_score                              25-34 years                      -0.163  111
# 111              drivers_communication_score                              25-34 years                      -0.123  112
# 112               drivers_waiting_time_score                              45-54 years                      -0.354  113
# 113                 drivers_timeliness_score                              45-54 years                      -0.135  114
# 114              drivers_communication_score                              45-54 years                      -0.106  115
# 115               drivers_waiting_time_score                              18-24 years                      -0.483  116
# 116                 drivers_timeliness_score                              18-24 years                      -0.184  117
# 117              drivers_communication_score                              18-24 years                      -0.090  118
# 118               drivers_waiting_time_score                              35-44 years                      -0.350  119
# 119                 drivers_timeliness_score                              35-44 years                      -0.183  120
# 120              drivers_communication_score                              35-44 years                      -0.115  121

# %%
rb_tree.rename(columns= {'root':'parent_id', 'child':'name'}, inplace = True)

# %%
#rb_tree['id'] = rb_tree['parent_id'] + "__" + str(rb_tree['id'])

# %%
#rb_tree['id'][0] = 'ICCS'
# Out:
# <ipython-input-44-be3a711aed33>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rb_tree['id'][0] = 'ICCS'

# %%
rb_tree['id'] = rb_tree['id'].apply(str)

# %%
rb_tree['id'] = rb_tree['id'] + "a"

# %%
rb_tree
# Out:
#                                         name                                parent_id  emotional_engagement_score    id
# 0                                       ICCS                                      NaN                         NaN    1a
# 1                                    Ontario                                     ICCS                      -0.453    2a
# 2                                   Manitoba                                     ICCS                      -0.413    3a
# 3                                       Peel                                     ICCS                      -0.392    4a
# 4                       Prefer not to answer                                  Ontario                      -0.581    5a
# 5                 Student, full or part time                                  Ontario                      -0.572    6a
# 6    Paid employment, part time or full time                                  Ontario                      -0.559    7a
# 7                       Prefer not to answer                                 Manitoba                      -0.829    8a
# 8    Paid employment, part time or full time                                 Manitoba                      -0.487    9a
# 9                                    Retired                                 Manitoba                      -0.483   10a
# 10                      Prefer not to answer                                     Peel                      -0.966   11a
# 11                                     Other                                     Peel                      -0.592   12a
# 12                Student, full or part time                                     Peel                      -0.576   13a
# 13                               25-34 years                     Prefer not to answer                      -0.764   14a
# 14                               45-54 years                     Prefer not to answer                      -0.534   15a
# 15                                 75+ years                     Prefer not to answer                      -0.448   16a
# 16                               45-54 years               Student, full or part time                      -0.824   17a
# 17                               18-24 years               Student, full or part time                      -0.420   18a
# 18                               35-44 years               Student, full or part time                      -0.366   19a
# 19                               18-24 years  Paid employment, part time or full time                      -0.448   20a
# 20                               55-64 years  Paid employment, part time or full time                      -0.396   21a
# 21                               35-44 years  Paid employment, part time or full time                      -0.296   22a
# 22                               25-34 years                     Prefer not to answer                      -0.764   23a
# 23                               45-54 years                     Prefer not to answer                      -0.534   24a
# 24                                 75+ years                     Prefer not to answer                      -0.448   25a
# 25                               18-24 years  Paid employment, part time or full time                      -0.448   26a
# 26                               55-64 years  Paid employment, part time or full time                      -0.396   27a
# 27                               35-44 years  Paid employment, part time or full time                      -0.296   28a
# 28                               35-44 years                                  Retired                      -0.769   29a
# 29                               45-54 years                                  Retired                      -0.498   30a
# 30                               55-64 years                                  Retired                      -0.227   31a
# 31                               25-34 years                     Prefer not to answer                      -0.764   32a
# 32                               45-54 years                     Prefer not to answer                      -0.534   33a
# 33                                 75+ years                     Prefer not to answer                      -0.448   34a
# 34                               18-24 years                                    Other                      -0.425   35a
# 35                               55-64 years                                    Other                      -0.377   36a
# 36                               25-34 years                                    Other                      -0.330   37a
# 37                               45-54 years               Student, full or part time                      -0.824   38a
# 38                               18-24 years               Student, full or part time                      -0.420   39a
# 39                               35-44 years               Student, full or part time                      -0.366   40a
# 40                drivers_waiting_time_score                              25-34 years                      -0.336   41a
# 41                  drivers_timeliness_score                              25-34 years                      -0.163   42a
# 42               drivers_communication_score                              25-34 years                      -0.123   43a
# 43                drivers_waiting_time_score                              45-54 years                      -0.354   44a
# 44                  drivers_timeliness_score                              45-54 years                      -0.135   45a
# 45               drivers_communication_score                              45-54 years                      -0.106   46a
# 46                        drivers_care_score                                75+ years                      -0.677   47a
# 47                     drivers_outcome_score                                75+ years                      -0.022   48a
# 48                  drivers_positivity_score                                75+ years                      -0.007   49a
# 49                drivers_waiting_time_score                              45-54 years                      -0.354   50a
# 50                  drivers_timeliness_score                              45-54 years                      -0.135   51a
# 51               drivers_communication_score                              45-54 years                      -0.106   52a
# 52                drivers_waiting_time_score                              18-24 years                      -0.483   53a
# 53                  drivers_timeliness_score                              18-24 years                      -0.184   54a
# 54               drivers_communication_score                              18-24 years                      -0.090   55a
# 55                drivers_waiting_time_score                              35-44 years                      -0.350   56a
# 56                  drivers_timeliness_score                              35-44 years                      -0.183   57a
# 57               drivers_communication_score                              35-44 years                      -0.115   58a
# 58                drivers_waiting_time_score                              18-24 years                      -0.483   59a
# 59                  drivers_timeliness_score                              18-24 years                      -0.184   60a
# 60               drivers_communication_score                              18-24 years                      -0.090   61a
# 61                drivers_waiting_time_score                              55-64 years                      -0.349   62a
# 62                  drivers_timeliness_score                              55-64 years                      -0.154   63a
# 63               drivers_communication_score                              55-64 years                      -0.100   64a
# 64                drivers_waiting_time_score                              35-44 years                      -0.350   65a
# 65                  drivers_timeliness_score                              35-44 years                      -0.183   66a
# 66               drivers_communication_score                              35-44 years                      -0.115   67a
# 67                drivers_waiting_time_score                              25-34 years                      -0.336   68a
# 68                  drivers_timeliness_score                              25-34 years                      -0.163   69a
# 69               drivers_communication_score                              25-34 years                      -0.123   70a
# 70                drivers_waiting_time_score                              45-54 years                      -0.354   71a
# 71                  drivers_timeliness_score                              45-54 years                      -0.135   72a
# 72               drivers_communication_score                              45-54 years                      -0.106   73a
# 73                        drivers_care_score                                75+ years                      -0.677   74a
# 74                     drivers_outcome_score                                75+ years                      -0.022   75a
# 75                  drivers_positivity_score                                75+ years                      -0.007   76a
# 76                drivers_waiting_time_score                              18-24 years                      -0.483   77a
# 77                  drivers_timeliness_score                              18-24 years                      -0.184   78a
# 78               drivers_communication_score                              18-24 years                      -0.090   79a
# 79                drivers_waiting_time_score                              55-64 years                      -0.349   80a
# 80                  drivers_timeliness_score                              55-64 years                      -0.154   81a
# 81               drivers_communication_score                              55-64 years                      -0.100   82a
# 82                drivers_waiting_time_score                              35-44 years                      -0.350   83a
# 83                  drivers_timeliness_score                              35-44 years                      -0.183   84a
# 84               drivers_communication_score                              35-44 years                      -0.115   85a
# 85                drivers_waiting_time_score                              35-44 years                      -0.350   86a
# 86                  drivers_timeliness_score                              35-44 years                      -0.183   87a
# 87               drivers_communication_score                              35-44 years                      -0.115   88a
# 88                drivers_waiting_time_score                              45-54 years                      -0.354   89a
# 89                  drivers_timeliness_score                              45-54 years                      -0.135   90a
# 90               drivers_communication_score                              45-54 years                      -0.106   91a
# 91                drivers_waiting_time_score                              55-64 years                      -0.349   92a
# 92                  drivers_timeliness_score                              55-64 years                      -0.154   93a
# 93               drivers_communication_score                              55-64 years                      -0.100   94a
# 94                drivers_waiting_time_score                              25-34 years                      -0.336   95a
# 95                  drivers_timeliness_score                              25-34 years                      -0.163   96a
# 96               drivers_communication_score                              25-34 years                      -0.123   97a
# 97                drivers_waiting_time_score                              45-54 years                      -0.354   98a
# 98                  drivers_timeliness_score                              45-54 years                      -0.135   99a
# 99               drivers_communication_score                              45-54 years                      -0.106  100a
# 100                       drivers_care_score                                75+ years                      -0.677  101a
# 101                    drivers_outcome_score                                75+ years                      -0.022  102a
# 102                 drivers_positivity_score                                75+ years                      -0.007  103a
# 103               drivers_waiting_time_score                              18-24 years                      -0.483  104a
# 104                 drivers_timeliness_score                              18-24 years                      -0.184  105a
# 105              drivers_communication_score                              18-24 years                      -0.090  106a
# 106               drivers_waiting_time_score                              55-64 years                      -0.349  107a
# 107                 drivers_timeliness_score                              55-64 years                      -0.154  108a
# 108              drivers_communication_score                              55-64 years                      -0.100  109a
# 109               drivers_waiting_time_score                              25-34 years                      -0.336  110a
# 110                 drivers_timeliness_score                              25-34 years                      -0.163  111a
# 111              drivers_communication_score                              25-34 years                      -0.123  112a
# 112               drivers_waiting_time_score                              45-54 years                      -0.354  113a
# 113                 drivers_timeliness_score                              45-54 years                      -0.135  114a
# 114              drivers_communication_score                              45-54 years                      -0.106  115a
# 115               drivers_waiting_time_score                              18-24 years                      -0.483  116a
# 116                 drivers_timeliness_score                              18-24 years                      -0.184  117a
# 117              drivers_communication_score                              18-24 years                      -0.090  118a
# 118               drivers_waiting_time_score                              35-44 years                      -0.350  119a
# 119                 drivers_timeliness_score                              35-44 years                      -0.183  120a
# 120              drivers_communication_score                              35-44 years                      -0.115  121a

# %%
connection = pg.connect('postgresql://aidatabases:Aidatabases#@65.1.96.15:5432/pathos_db')
engine = create_engine('postgresql://aidatabases:Aidatabases#@65.1.96.15:5432/pathos_db')

# %%
push_table_pgres(rb_tree, df_name = 'iccs_tree_june', schema= 'pathos_iccs_schema')

# %%
# sql_schema='''ALTER TABLE pathos_rb_schema.rb_tree_june
# ALTER COLUMN id TYPE text,
# ALTER COLUMN root TYPE text,
# ALTER COLUMN child TYPE text
# '''
# engine.execute(sql_schema)

# %%
rb_tree
# Out:
#                                         name                                parent_id  emotional_engagement_score                                                 id
# 0                                       ICCS                                      NaN                         NaN                                               ICCS
# 1                                    Ontario                                     ICCS                      -0.453                                      ICCS__Ontario
# 2                                   Manitoba                                     ICCS                      -0.413                                     ICCS__Manitoba
# 3                                       Peel                                     ICCS                      -0.392                                         ICCS__Peel
# 4                       Prefer not to answer                                  Ontario                      -0.581                      Ontario__Prefer not to answer
# 5                 Student, full or part time                                  Ontario                      -0.572                Ontario__Student, full or part time
# 6    Paid employment, part time or full time                                  Ontario                      -0.559   Ontario__Paid employment, part time or full time
# 7                       Prefer not to answer                                 Manitoba                      -0.829                     Manitoba__Prefer not to answer
# 8    Paid employment, part time or full time                                 Manitoba                      -0.487  Manitoba__Paid employment, part time or full time
# 9                                    Retired                                 Manitoba                      -0.483                                  Manitoba__Retired
# 10                      Prefer not to answer                                     Peel                      -0.966                         Peel__Prefer not to answer
# 11                                     Other                                     Peel                      -0.592                                        Peel__Other
# 12                Student, full or part time                                     Peel                      -0.576                   Peel__Student, full or part time
# 13                               25-34 years                     Prefer not to answer                      -0.764                  Prefer not to answer__25-34 years
# 14                               45-54 years                     Prefer not to answer                      -0.534                  Prefer not to answer__45-54 years
# 15                                 75+ years                     Prefer not to answer                      -0.448                    Prefer not to answer__75+ years
# 16                               45-54 years               Student, full or part time                      -0.824            Student, full or part time__45-54 years
# 17                               18-24 years               Student, full or part time                      -0.420            Student, full or part time__18-24 years
# 18                               35-44 years               Student, full or part time                      -0.366            Student, full or part time__35-44 years
# 19                               18-24 years  Paid employment, part time or full time                      -0.448  Paid employment, part time or full time__18-24...
# 20                               55-64 years  Paid employment, part time or full time                      -0.396  Paid employment, part time or full time__55-64...
# 21                               35-44 years  Paid employment, part time or full time                      -0.296  Paid employment, part time or full time__35-44...
# 22                               25-34 years                     Prefer not to answer                      -0.764                  Prefer not to answer__25-34 years
# 23                               45-54 years                     Prefer not to answer                      -0.534                  Prefer not to answer__45-54 years
# 24                                 75+ years                     Prefer not to answer                      -0.448                    Prefer not to answer__75+ years
# 25                               18-24 years  Paid employment, part time or full time                      -0.448  Paid employment, part time or full time__18-24...
# 26                               55-64 years  Paid employment, part time or full time                      -0.396  Paid employment, part time or full time__55-64...
# 27                               35-44 years  Paid employment, part time or full time                      -0.296  Paid employment, part time or full time__35-44...
# 28                               35-44 years                                  Retired                      -0.769                               Retired__35-44 years
# 29                               45-54 years                                  Retired                      -0.498                               Retired__45-54 years
# 30                               55-64 years                                  Retired                      -0.227                               Retired__55-64 years
# 31                               25-34 years                     Prefer not to answer                      -0.764                  Prefer not to answer__25-34 years
# 32                               45-54 years                     Prefer not to answer                      -0.534                  Prefer not to answer__45-54 years
# 33                                 75+ years                     Prefer not to answer                      -0.448                    Prefer not to answer__75+ years
# 34                               18-24 years                                    Other                      -0.425                                 Other__18-24 years
# 35                               55-64 years                                    Other                      -0.377                                 Other__55-64 years
# 36                               25-34 years                                    Other                      -0.330                                 Other__25-34 years
# 37                               45-54 years               Student, full or part time                      -0.824            Student, full or part time__45-54 years
# 38                               18-24 years               Student, full or part time                      -0.420            Student, full or part time__18-24 years
# 39                               35-44 years               Student, full or part time                      -0.366            Student, full or part time__35-44 years
# 40                drivers_waiting_time_score                              25-34 years                      -0.336            25-34 years__drivers_waiting_time_score
# 41                  drivers_timeliness_score                              25-34 years                      -0.163              25-34 years__drivers_timeliness_score
# 42               drivers_communication_score                              25-34 years                      -0.123           25-34 years__drivers_communication_score
# 43                drivers_waiting_time_score                              45-54 years                      -0.354            45-54 years__drivers_waiting_time_score
# 44                  drivers_timeliness_score                              45-54 years                      -0.135              45-54 years__drivers_timeliness_score
# 45               drivers_communication_score                              45-54 years                      -0.106           45-54 years__drivers_communication_score
# 46                        drivers_care_score                                75+ years                      -0.677                      75+ years__drivers_care_score
# 47                     drivers_outcome_score                                75+ years                      -0.022                   75+ years__drivers_outcome_score
# 48                  drivers_positivity_score                                75+ years                      -0.007                75+ years__drivers_positivity_score
# 49                drivers_waiting_time_score                              45-54 years                      -0.354            45-54 years__drivers_waiting_time_score
# 50                  drivers_timeliness_score                              45-54 years                      -0.135              45-54 years__drivers_timeliness_score
# 51               drivers_communication_score                              45-54 years                      -0.106           45-54 years__drivers_communication_score
# 52                drivers_waiting_time_score                              18-24 years                      -0.483            18-24 years__drivers_waiting_time_score
# 53                  drivers_timeliness_score                              18-24 years                      -0.184              18-24 years__drivers_timeliness_score
# 54               drivers_communication_score                              18-24 years                      -0.090           18-24 years__drivers_communication_score
# 55                drivers_waiting_time_score                              35-44 years                      -0.350            35-44 years__drivers_waiting_time_score
# 56                  drivers_timeliness_score                              35-44 years                      -0.183              35-44 years__drivers_timeliness_score
# 57               drivers_communication_score                              35-44 years                      -0.115           35-44 years__drivers_communication_score
# 58                drivers_waiting_time_score                              18-24 years                      -0.483            18-24 years__drivers_waiting_time_score
# 59                  drivers_timeliness_score                              18-24 years                      -0.184              18-24 years__drivers_timeliness_score
# 60               drivers_communication_score                              18-24 years                      -0.090           18-24 years__drivers_communication_score
# 61                drivers_waiting_time_score                              55-64 years                      -0.349            55-64 years__drivers_waiting_time_score
# 62                  drivers_timeliness_score                              55-64 years                      -0.154              55-64 years__drivers_timeliness_score
# 63               drivers_communication_score                              55-64 years                      -0.100           55-64 years__drivers_communication_score
# 64                drivers_waiting_time_score                              35-44 years                      -0.350            35-44 years__drivers_waiting_time_score
# 65                  drivers_timeliness_score                              35-44 years                      -0.183              35-44 years__drivers_timeliness_score
# 66               drivers_communication_score                              35-44 years                      -0.115           35-44 years__drivers_communication_score
# 67                drivers_waiting_time_score                              25-34 years                      -0.336            25-34 years__drivers_waiting_time_score
# 68                  drivers_timeliness_score                              25-34 years                      -0.163              25-34 years__drivers_timeliness_score
# 69               drivers_communication_score                              25-34 years                      -0.123           25-34 years__drivers_communication_score
# 70                drivers_waiting_time_score                              45-54 years                      -0.354            45-54 years__drivers_waiting_time_score
# 71                  drivers_timeliness_score                              45-54 years                      -0.135              45-54 years__drivers_timeliness_score
# 72               drivers_communication_score                              45-54 years                      -0.106           45-54 years__drivers_communication_score
# 73                        drivers_care_score                                75+ years                      -0.677                      75+ years__drivers_care_score
# 74                     drivers_outcome_score                                75+ years                      -0.022                   75+ years__drivers_outcome_score
# 75                  drivers_positivity_score                                75+ years                      -0.007                75+ years__drivers_positivity_score
# 76                drivers_waiting_time_score                              18-24 years                      -0.483            18-24 years__drivers_waiting_time_score
# 77                  drivers_timeliness_score                              18-24 years                      -0.184              18-24 years__drivers_timeliness_score
# 78               drivers_communication_score                              18-24 years                      -0.090           18-24 years__drivers_communication_score
# 79                drivers_waiting_time_score                              55-64 years                      -0.349            55-64 years__drivers_waiting_time_score
# 80                  drivers_timeliness_score                              55-64 years                      -0.154              55-64 years__drivers_timeliness_score
# 81               drivers_communication_score                              55-64 years                      -0.100           55-64 years__drivers_communication_score
# 82                drivers_waiting_time_score                              35-44 years                      -0.350            35-44 years__drivers_waiting_time_score
# 83                  drivers_timeliness_score                              35-44 years                      -0.183              35-44 years__drivers_timeliness_score
# 84               drivers_communication_score                              35-44 years                      -0.115           35-44 years__drivers_communication_score
# 85                drivers_waiting_time_score                              35-44 years                      -0.350            35-44 years__drivers_waiting_time_score
# 86                  drivers_timeliness_score                              35-44 years                      -0.183              35-44 years__drivers_timeliness_score
# 87               drivers_communication_score                              35-44 years                      -0.115           35-44 years__drivers_communication_score
# 88                drivers_waiting_time_score                              45-54 years                      -0.354            45-54 years__drivers_waiting_time_score
# 89                  drivers_timeliness_score                              45-54 years                      -0.135              45-54 years__drivers_timeliness_score
# 90               drivers_communication_score                              45-54 years                      -0.106           45-54 years__drivers_communication_score
# 91                drivers_waiting_time_score                              55-64 years                      -0.349            55-64 years__drivers_waiting_time_score
# 92                  drivers_timeliness_score                              55-64 years                      -0.154              55-64 years__drivers_timeliness_score
# 93               drivers_communication_score                              55-64 years                      -0.100           55-64 years__drivers_communication_score
# 94                drivers_waiting_time_score                              25-34 years                      -0.336            25-34 years__drivers_waiting_time_score
# 95                  drivers_timeliness_score                              25-34 years                      -0.163              25-34 years__drivers_timeliness_score
# 96               drivers_communication_score                              25-34 years                      -0.123           25-34 years__drivers_communication_score
# 97                drivers_waiting_time_score                              45-54 years                      -0.354            45-54 years__drivers_waiting_time_score
# 98                  drivers_timeliness_score                              45-54 years                      -0.135              45-54 years__drivers_timeliness_score
# 99               drivers_communication_score                              45-54 years                      -0.106           45-54 years__drivers_communication_score
# 100                       drivers_care_score                                75+ years                      -0.677                      75+ years__drivers_care_score
# 101                    drivers_outcome_score                                75+ years                      -0.022                   75+ years__drivers_outcome_score
# 102                 drivers_positivity_score                                75+ years                      -0.007                75+ years__drivers_positivity_score
# 103               drivers_waiting_time_score                              18-24 years                      -0.483            18-24 years__drivers_waiting_time_score
# 104                 drivers_timeliness_score                              18-24 years                      -0.184              18-24 years__drivers_timeliness_score
# 105              drivers_communication_score                              18-24 years                      -0.090           18-24 years__drivers_communication_score
# 106               drivers_waiting_time_score                              55-64 years                      -0.349            55-64 years__drivers_waiting_time_score
# 107                 drivers_timeliness_score                              55-64 years                      -0.154              55-64 years__drivers_timeliness_score
# 108              drivers_communication_score                              55-64 years                      -0.100           55-64 years__drivers_communication_score
# 109               drivers_waiting_time_score                              25-34 years                      -0.336            25-34 years__drivers_waiting_time_score
# 110                 drivers_timeliness_score                              25-34 years                      -0.163              25-34 years__drivers_timeliness_score
# 111              drivers_communication_score                              25-34 years                      -0.123           25-34 years__drivers_communication_score
# 112               drivers_waiting_time_score                              45-54 years                      -0.354            45-54 years__drivers_waiting_time_score
# 113                 drivers_timeliness_score                              45-54 years                      -0.135              45-54 years__drivers_timeliness_score
# 114              drivers_communication_score                              45-54 years                      -0.106           45-54 years__drivers_communication_score
# 115               drivers_waiting_time_score                              18-24 years                      -0.483            18-24 years__drivers_waiting_time_score
# 116                 drivers_timeliness_score                              18-24 years                      -0.184              18-24 years__drivers_timeliness_score
# 117              drivers_communication_score                              18-24 years                      -0.090           18-24 years__drivers_communication_score
# 118               drivers_waiting_time_score                              35-44 years                      -0.350            35-44 years__drivers_waiting_time_score
# 119                 drivers_timeliness_score                              35-44 years                      -0.183              35-44 years__drivers_timeliness_score
# 120              drivers_communication_score                              35-44 years                      -0.115           35-44 years__drivers_communication_score
