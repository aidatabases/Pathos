# %% [markdown]
# # Querying Postgres

# %%
from pathos_config import *

# %%
dim_schema = 'pathos_iccs_schema_test2'

# %% [markdown]
# ## Selecting Relevant Dimensions based on Master Dim Table + Filtering based on (Active for reporting)

# %% [markdown]
# ### reference schema

# %%
for i in range(len(ref_table_list)):
    sample_var = ref_table_list[i]
    print(sample_var)
    vars()[sample_var]= load_data(ref_table_list[i], 'pathos_reference_common_schema', connection)
# Out:
# pathos_ref_emotions
# pathos_ref_sectors
# pathos_ref_drivers
# pathos_ref_drivers_sectors_mapping
# pathos_ref_clients

# %%
# Applying Filter
pathos_ref_drivers_sectors_mapping = pathos_ref_drivers_sectors_mapping.loc[pathos_ref_drivers_sectors_mapping['sector_reporting_flag']=='Y']

# %% [markdown]
# ### dimension schema

# %%
for i in range(len(dim_table_list_iccs)):
    sample_var = dim_table_list_iccs[i]
    print(sample_var)
    vars()[sample_var]= load_data(dim_table_list_iccs[i], dim_schema, connection)
# Out:
# pathos_cl_master_dim_mapping
# pathos_cl_master_time
# pathos_cl_master_time_new
# pathos_cl_master_prod_serv_cf7
# pathos_cl_master_prod_serv_cf8
# pathos_cl_master_prod_serv_cf20
# pathos_cl_master_prod_ver
# pathos_cl_master_channel
# pathos_cl_master_age
# pathos_cl_master_gender
# pathos_cl_master_income
# pathos_cl_master_occupation
# pathos_cl_master_education
# pathos_cl_master_country
# pathos_cl_master_personas

# %%
# Applying Filter
try:
    pathos_cl_master_dim_mapping = active_filter(pathos_cl_master_dim_mapping)
except:
    print('not available')
try:
    pathos_cl_master_time = active_filter(pathos_cl_master_time)
except:
    print('not available')
    
try:
    pathos_cl_master_time_new = active_filter(pathos_cl_master_time_new)
except:
    print('not available')
    
try:
    pathos_cl_master_prod_serv_cf8 = active_filter(pathos_cl_master_prod_serv_cf8)
except:
    print('not available')
    
try:
    pathos_cl_master_prod_serv_cf7 = active_filter(pathos_cl_master_prod_serv_cf7)
except:
    print('not available')
    
try:
    pathos_cl_master_prod_serv_cf20 = active_filter(pathos_cl_master_prod_serv_20)
except:
    print('not available')


try:
    pathos_cl_master_channel = active_filter(pathos_cl_master_channel)
except:
    print('not available')
        
try:
    pathos_cl_master_age = active_filter(pathos_cl_master_age)
except:
    print('not available')
        
try:
    pathos_cl_master_gender = active_filter(pathos_cl_master_gender)
except:
    print('not available')
        
try:
    pathos_cl_master_income = active_filter(pathos_cl_master_income)
except:
    print('not available')
        
try:
    pathos_cl_master_occupation = active_filter(pathos_cl_master_occupation)
except:
    print('not available')
    
try:
    pathos_cl_master_education = active_filter(pathos_cl_master_education)
except:
    print('not available')
    
try:
    pathos_cl_master_country = active_filter(pathos_cl_master_country)
except:
    print('not available')
    
try:
    pathos_cl_master_personas = active_filter(pathos_cl_master_personas)
except:
    print('not available')
    
try:
    pathos_cl_master_prod_ver = active_filter(pathos_cl_master_prod_ver)
except:
    print('not available')
# Out:
# not available
# not available

# %% [markdown]
# ### generic schema

# %%
connection = pg.connect('postgresql://aidatabases:Aidatabases#@34.93.95.15:5432/pathos_db')
engine = create_engine('postgresql://aidatabases:Aidatabases#@34.93.95.15:5432/pathos_db')

# %%
cf7 = psql.read_sql('SELECT * FROM {}.cf7'.format(dim_schema), connection)
#cf7_verbatim = psql.read_sql('SELECT * FROM pathos_iccs_schema.cf7_verbatim', connection)
cf8 = psql.read_sql('SELECT * FROM {}.cf8'.format(dim_schema), connection)
#cf8_verbatim = psql.read_sql('SELECT * FROM pathos_iccs_schema.cf8_verbatim', connection)
# cf20 = psql.read_sql('SELECT * FROM {}.cf20'.format(dim_schema), connection)

# %% [markdown]
# ## Dimensions based on filters

# %% [markdown]
# # CF8

# %%
keys = ['Q5A_1','Q5A_2','Q5A_3','Q5A_4','Q5A_5','Q5A_6','Q5A_7','Q5A_8','Q5A_9','Q5A_10','Q5B_1','Q5B_2','Q5B_3','Q5B_4','Q5B_5',
     'Q5B_6','Q5B_7','Q5B_8','Q5B_9','Q6_1','Q6_2','Q6_3','Q6_4','Q6_5','Q6_6','Q6_7','Q6_8','Q6_9','Q6_10','Q6_11','Q8A_1',
     'Q8A_2','Q8A_3','Q8A_4','Q8A_5','Q8A_6','Q8A_7','Q8A_8','Q8A_9','Q8B_1','Q8B_2','Q8B_3','Q8B_4','Q8B_5','Q8B_6','Q8C_1',
     'Q8C_2','Q8C_3','Q8C_4','Q8C_5','Q8C_6','Q8D_1','Q8D_2','Q8D_3','Q8D_4','Q8D_5','Q8E_1','Q8E_2','Q8E_3','Q8E_4','Q8F_1',
     'Q8F_2','Q8F_3','Q8F_4','Q8F_5','Q8F_6','Q8F_7','Q8F_8','Q8G_1','Q8G_2','Q8G_3','Q8G_4','Q8G_5','Q8G_6','Q8G_7','Q8G_8', 
     'Q8G_9']
values = ['q5a_1','q5a_2','q5a_3','q5a_4','q5a_5','q5a_6','q5a_7','q5a_8','q5a_9','q5a_10','q5b_1','q5b_2','q5b_3','q5b_4','q5b_5',
     'q5b_6','q5b_7','q5b_8','q5b_9','q6_1','q6_2','q6_3','q6_4','q6_5','q6_6','q6_7','q6_8','q6_9','q6_10','q6_11','q8a_1',
     'q8a_2','q8a_3','q8a_4','q8a_5','q8a_6','q8a_7','q8a_8','q8a_9','q8b_1','q8b_2','q8b_3','q8b_4','q8b_5','q8b_6','q8c_1',
     'q8c_2','q8c_3','q8c_4','q8c_5','q8c_6','q8d_1','q8d_2','q8d_3','q8d_4','q8d_5','q8e_1','q8e_2','q8e_3','q8e_4','q8f_1',
     'q8f_2','q8f_3','q8f_4','q8f_5','q8f_6','q8f_7','q8f_8','q8g_1','q8g_2','q8g_3','q8g_4','q8g_5','q8g_6','q8g_7','q8g_8', 
     'q8g_9']
rename_dict = dict(zip(keys, values))

# %%
cf8 = cf8.rename(columns=rename_dict)

# %%
##CF8
# to dictionary
#d = cf8_ques_id.set_index('Questions').to_dict()['ques_id']
d = pathos_cl_master_prod_serv_cf8.set_index('dim_value_name').to_dict()
cf8 = cf8.rename(columns=rename_dict) 

cf8_ques_id_list = pathos_cl_master_prod_serv_cf8['dim_val_id'].tolist()
cf8_ques_list = pathos_cl_master_prod_serv_cf8['dim_value_name'].tolist()

#index of columns
[cf8.columns.get_loc(c) for c in cf8_ques_list if c in cf8]

#copy of dataframe
cf8_temp = cf8.iloc[:,[cf8.columns.get_loc(c) for c in cf8_ques_list if c in cf8][0]:[cf8.columns.get_loc(c) for c in cf8_ques_list if c in cf8][-1]+1].copy()

#rename columns in cf8_temp
cf8_temp.columns = cf8_temp.columns.to_series().map(d['dim_val_id'])

#concatenation
cf8 = pd.concat([cf8, cf8_temp], axis=1)

# rename id
cf8 = cf8.rename(columns={'id': 'respondent_id'})

# %% [markdown]
# ## Adding Dimension ID

# %% [markdown]
# ### Adding time dimension to cf8

# %%
cf8.insert(0, 'TimeStamp', pd.to_datetime('2018-01-23 16:46:22').replace(microsecond=0))
cf8['Qtr'] = pd.to_datetime(cf8.TimeStamp).dt.quarter
cf8['year'] = cf8['TimeStamp'].dt.year
cf8['year']= cf8["year"].astype(str)
cf8['Qtr']=cf8["Qtr"].astype(str)
cf8['Period_id'] = cf8[['year', 'Qtr']].agg('_0'.join, axis=1)

# %%
#REPLACING BRAND NAME WITH BRAND ID
try:
    s = cf8.year.replace(pathos_cl_master_time.set_index('dim_value_name')['dim_val_id'])
    cf8['time_id'] = s
except:
    print('not available')

# %% [markdown]
# ### cf8 & channel dimension

# %%
p = ['Q11_01','Q11_02','Q11_03','Q11_04','Q11_05','Q11_06','Q11_07','Q11_08','Q11_09','Q11_10','Q11_11','Q11_12','Q11_13','Q11_14','Q11_15']
s = cf8[['Q11_01','Q11_02','Q11_03','Q11_04','Q11_05','Q11_06','Q11_07','Q11_08','Q11_09','Q11_10','Q11_11','Q11_12','Q11_13','Q11_14','Q11_15']]
# s = s.notna()
# for i in p:
#     s[i] = s[i].astype(int)

cf8['channel'] = s.idxmax(axis=1)

# %%
cf8['channel'] = cf8['channel'].map({'Q11_02': 'Telephone', 'Q11_01':'In-person',
       'Q11_03': 'Online','Q11_04':'Online', 'Q11_08': 'Mail',
       'Q11_05':'Telephone', 'Q11_07':'Online', 'Q11_10':'In-person',
       'Q11_09':'Telephone', 'Q11_06':'Online', 'Q11_11':'In-person', 'Q11_12':'unknown', 'Q11_13':'unknown',
                                            'Q11_14':'unknown','Q11_15':'unknown', np.nan:'unknown'})

# %%
#REPLACING BRAND NAME WITH BRAND ID
try:
    s = cf8.channel.replace(pathos_cl_master_channel.set_index('dim_value_name')['dim_val_id'])
    cf8['channel_id'] = s
except:
    print('not available')

# %%
cf8['channel'].unique()
# Out:
# array(['unknown', 'In-person', 'Telephone', 'Online', 'Mail'],
#       dtype=object)

# %% [markdown]
# ### Demographic reference

# %%
cf8.rename(columns={'Q29': 'gender', 'Q30':'age', 'Q35':'occupation','Q38':'income'}, inplace= True)

# %%
# int to string
cf8.gender = cf8.gender.astype(str)

# %%
cf8['gender'] = cf8['gender'].replace({'4':'3', np.nan:'3'})

# %%
# int to string
cf8.gender = cf8.gender.astype(str)

#REPLACING BRAND NAME WITH BRAND ID
try:
    s = cf8.gender.replace(pathos_cl_master_gender.set_index('dim_value_name')['dim_val_id'])
    cf8['gender_id'] = s
except:
    print('not available')

# %%
cf8['gender_id'].unique()
# Out:
# array([  2., 701.,   3.])

# %% [markdown]
# # age dimension

# %%
# int to string
cf8.age = cf8.age.astype(str)

# %%
cf8.age.unique()
# Out:
# array(['6', '4', '3', '5', '10', '7', '2', '1', '9'], dtype=object)

# %%
cf8['age'] = cf8['age'].replace({'8':'-1','9':'-1', '10':'-1',
                    np.nan:'-1'})

# %%
# int to string
cf8.age = cf8.age.astype(str)

#REPLACING BRAND NAME WITH BRAND ID
try:
    s = cf8.age.replace(pathos_cl_master_age.set_index('dim_value_name')['dim_val_id'])
    cf8['age_id'] = s
except:
    print('not available')

# %% [markdown]
# # Occupation dimension

# %%
# int to string
cf8.occupation = cf8.occupation.astype(str)

# %%
cf8.occupation.unique()
# Out:
# array(['5', '1', '4', '10', '6', '7', '2', '8', '3'], dtype=object)

# %%
cf8['occupation'] = cf8['occupation'].replace({'8':'-1', '9':'-1','10':'-1' , np.nan:'-1'})

# %%
# int to string
cf8.occupation = cf8.occupation.astype(str)

#REPLACING BRAND NAME WITH BRAND ID
try:
    s = cf8.occupation.replace(pathos_cl_master_occupation.set_index('dim_value_name')['dim_val_id'])
    cf8['occupation_id'] = s
except:
    print('not available')

# %% [markdown]
# # income dimension

# %%
cf8.income.unique()
# Out:
# array([ 5, 10,  4,  8,  6,  1,  3,  9,  7, 13,  2, 11, 12], dtype=int64)

# %%
# int to string
cf8.income = cf8.income.astype(str)
cf8['income'] = cf8['income'].replace({'11':'-1','12':'-1', '13':'-1',
                     np.nan:'-1'})

# %%
# int to string
cf8.income = cf8.income.astype(str)

#REPLACING BRAND NAME WITH BRAND ID
try:
    s = cf8.income.replace(pathos_cl_master_income.set_index('dim_value_name')['dim_val_id'])
    cf8['income_id'] = s
except:
    print('not available')

# %% [markdown]
# # Jurisdiction

# %%
# #REPLACING BRAND NAME WITH BRAND ID
try:
    s = cf8.jurisdiction.replace(pathos_cl_master_country.set_index('dim_value_name')['dim_val_id'])
    cf8['location_id'] = s
except:
    print('not available')
# Out:
# not available

# %%
cf8 = cf8.rename(columns={'Respondent_Serial': 'id'})    #rename
pathos_cl_master_prod_serv_cf8_list = pathos_cl_master_prod_serv_cf8['dim_val_id'].tolist()
table_list = ['id', 'gender_id', 'age_id', 'occupation_id', 'income_id', 'channel_id', 'time_id']
final_list = table_list + pathos_cl_master_prod_serv_cf8_list
cf8 = cf8[final_list]

# %% [markdown]
# # Applying filters to Main DataFrame

# %%
pathos_cl_master_time
# Out:
#     dim_val_id dim_value_name dim_value_desc dim_active_reporting dim_active_processsing child_record  parent_record_id  hierarchy_level                       created_on created_by                       updated_on updated_by
# 0   810010.000           2020   2020 H2 Data                    Y                      Y            N        -99999.000            1.000 2021-06-20 18:22:18.700211+00:00     System 2021-06-20 18:22:18.700211+00:00     System
# 1   810011.000           2019   2019 H2 Data                    Y                      Y            N        -99999.000            1.000 2021-06-20 18:22:18.700211+00:00     System 2021-06-20 18:22:18.700211+00:00     System
# 2   810012.000           2018   2018 H2 Data                    Y                      Y            N        -99999.000            1.000 2021-06-20 18:22:18.700211+00:00     System 2021-06-20 18:22:18.700211+00:00     System
# 3   810013.000           2017   2017 H2 Data                    Y                      Y            N        -99999.000            1.000 2021-06-20 18:22:18.700211+00:00     System 2021-06-20 18:22:18.700211+00:00     System
# 4   810014.000           2016   2016 H2 Data                    Y                      Y            N        -99999.000            1.000 2021-06-20 18:22:18.700211+00:00     System 2021-06-20 18:22:18.700211+00:00     System
# 5   810015.000           2015   2015 H2 Data                    Y                      Y            N        -99999.000            1.000 2021-06-20 18:22:18.700211+00:00     System 2021-06-20 18:22:18.700211+00:00     System
# 6   810016.000           2014   2014 H2 Data                    Y                      Y            N        -99999.000            1.000 2021-06-20 18:22:18.700211+00:00     System 2021-06-20 18:22:18.700211+00:00     System
# 7   810017.000           2013   2013 H2 Data                    Y                      Y            N        -99999.000            1.000 2021-06-20 18:22:18.700211+00:00     System 2021-06-20 18:22:18.700211+00:00     System
# 8   810018.000           2012   2012 H2 Data                    Y                      Y            N        -99999.000            1.000 2021-06-20 18:22:18.700211+00:00     System 2021-06-20 18:22:18.700211+00:00     System
# 9   810019.000           2011   2011 H2 Data                    Y                      Y            N        -99999.000            1.000 2021-06-20 18:22:18.700211+00:00     System 2021-06-20 18:22:18.700211+00:00     System
# 10  810020.000           2010   2010 H2 Data                    Y                      Y            N        -99999.000            1.000 2021-06-20 18:22:18.700211+00:00     System 2021-06-20 18:22:18.700211+00:00     System
# 11  810021.000             -1        unknown                    Y                      Y            N        -99999.000            1.000 2021-06-20 18:22:18.700211+00:00     System 2021-06-20 18:22:18.700211+00:00     System

# %%
try:
    available_time = list(pathos_cl_master_time['dim_val_id'])
except:
    print('not available')
        
try:
    available_age = list(pathos_cl_master_age['dim_val_id'])
except:
    print('not available')
        
try:
    available_occupation = list(pathos_cl_master_occupation['dim_val_id'])
except:
    print('not available')
        
try:
    available_gender = list(pathos_cl_master_gender['dim_val_id'])
except:
    print('not available')
        
try:
    available_income = list(pathos_cl_master_income['dim_val_id'])
except:
    print('not available')
        
try:
    available_channel = list(pathos_cl_master_channel['dim_val_id'])
except:
    print('not available')

# %% [markdown]
# ### Applying Filter

# %%
try:
    cf8 = cf8.loc[cf8['time_id'].isin (available_time)]
except:
    print('not available')
        
try:
    cf8 = cf8.loc[cf8['age_id'].isin (available_age)]
except:
    print('not available')
        
try:
    cf8 = cf8.loc[cf8['gender_id'].isin (available_gender)]
except:
    print('not available')

try:
    cf8 = cf8.loc[cf8['income_id'].isin (available_income)]
except:
    print('not available')

try:
    cf8 = cf8.loc[cf8['occupation_id'].isin (available_occupation)]
except:
    print('not available')

try:
    cf8 = cf8.loc[cf8['channel_id'].isin (available_channel)]
except:
    print('not available')

# %%
ques_dict = pd.Series(pathos_cl_master_prod_serv_cf8.dim_value_name.values,index=pathos_cl_master_prod_serv_cf8.dim_val_id).to_dict()

# %%
cf8.rename(columns=ques_dict, inplace=True)

# %%
cf8
# Out:
#             id  gender_id  age_id  occupation_id  income_id  channel_id    time_id  q5a_1  q5a_2  q5a_3  q5a_6  q5a_7  q5a_9  q5a_10  q5b_3  q5b_5  q5b_6  q5b_7  q6_1  q6_2  q6_4  q6_5  q6_8  q6_10  q6_11  q8a_1  q8a_4  q8a_5  q8a_7  q8a_8  q8b_2  q8b_4  q8b_5  q8b_6  q8c_3  q8c_4  q8c_6  q8d_1  q8d_4  q8e_1  q8e_2  q8e_3  q8f_2  q8f_5  q8f_7  q8f_8  q8g_1  q8g_4  q8g_7  q8g_8  q8g_9
# 1     21000484    701.000 806.000        905.000   1010.000   55004.000 810012.000  2.000  5.000  5.000  5.000  4.000  5.000   5.000  5.000  4.000  6.000  5.000 6.000 6.000 6.000 6.000 4.000  6.000  5.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  5.000  6.000      4  4.000  4.000      5      6  5.000  5.000  4.000  4.000  3.000  5.000  5.000
# 3        80063    701.000 803.000        901.000   1008.000   55001.000 810012.000  5.000    NaN    NaN  4.000    NaN    NaN     NaN    NaN    NaN    NaN    NaN 6.000   NaN   NaN 6.000 5.000  5.000    NaN  6.000  6.000    NaN    NaN    NaN    NaN  6.000  6.000    NaN  6.000  6.000    NaN    NaN  6.000      5  6.000    NaN      6      2    NaN    NaN    NaN  6.000    NaN    NaN    NaN
# 4     21000460    701.000 806.000        905.000   1010.000   55004.000 810012.000  5.000  5.000  5.000  6.000  4.000  5.000   6.000  6.000  6.000  6.000  6.000 6.000 6.000 6.000 5.000 6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  9.000  9.000  9.000      9  9.000  9.000      5      9  5.000  9.000  9.000  9.000  9.000  9.000  9.000
# 5     21000136    701.000 806.000        905.000   1006.000   55003.000 810012.000  5.000  5.000  5.000  5.000  5.000  5.000   6.000  6.000  6.000  6.000  5.000 6.000 5.000 6.000 6.000 5.000  6.000  5.000  6.000  6.000  6.000  6.000  6.000  6.000  5.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000      6  6.000  6.000      6      6  5.000  6.000  6.000  5.000  6.000  6.000  1.000
# 8          802    701.000 806.000        905.000   1003.000   55005.000 810012.000  4.000  3.000  4.000  3.000  2.000  1.000   5.000  5.000  6.000  2.000  4.000   NaN   NaN   NaN   NaN   NaN    NaN    NaN  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000      6  6.000  6.000      6      5    NaN  6.000  6.000  6.000  6.000  6.000  6.000
# ...        ...        ...     ...            ...        ...         ...        ...    ...    ...    ...    ...    ...    ...     ...    ...    ...    ...    ...   ...   ...   ...   ...   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 4619    128835    701.000 804.000        901.000   1008.000   55004.000 810012.000  5.000  3.000  1.000  3.000  1.000  4.000   4.000  4.000  5.000    NaN  3.000 3.000 6.000 6.000 4.000 6.000  4.000  5.000  6.000  6.000  6.000  6.000  5.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000      6  4.000  4.000      6      6    NaN  6.000  6.000  3.000  6.000  6.000  1.000
# 4622    129124    701.000 804.000        905.000   1007.000   55001.000 810012.000  6.000  5.000  5.000  6.000  1.000  1.000   4.000  4.000  4.000    NaN  4.000 6.000 6.000 6.000 3.000 5.000  6.000  5.000  6.000  6.000  6.000  6.000  1.000  6.000  6.000  6.000  6.000  6.000  6.000  3.000  6.000  6.000      6  4.000  6.000      6      5    NaN  6.000  2.000  4.000  3.000  5.000  3.000
# 4623    129181    701.000 802.000        901.000   1004.000   55002.000 810012.000  3.000  4.000  4.000  4.000  5.000  4.000   4.000  4.000  4.000    NaN  5.000 6.000 4.000 6.000 6.000 4.000  6.000  4.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  3.000  6.000  6.000      6  6.000  6.000      6      5    NaN  6.000  3.000  3.000  6.000  6.000  6.000
# 4624    129204    701.000 805.000        905.000   1006.000   55005.000 810012.000  5.000  5.000  5.000  5.000  3.000  3.000   6.000  6.000  4.000    NaN  6.000 6.000 6.000 6.000 6.000 6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000  6.000      6  6.000  6.000      6      6    NaN  6.000  6.000  6.000  6.000  6.000  6.000
# 4625    129329    701.000 801.000        901.000   1003.000   55001.000 810012.000  4.000  4.000  3.000  2.000  5.000  5.000   4.000  4.000  3.000    NaN  4.000 6.000 5.000 4.000 6.000 4.000  5.000  4.000  5.000  3.000  5.000  4.000  4.000  3.000  3.000  4.000  4.000  4.000  2.000  4.000  4.000  4.000      3  4.000  3.000      4      4    NaN  3.000  5.000  2.000  3.000  5.000  4.000
#
# [2174 rows x 51 columns]

# %% [markdown]
# # CF 7

# %%
# keys = ['Q5_01', 'Q5_02','Q5_03','Q5_04','Q5_05','Q5_06','Q5_07','Q5_08','Q5_09','Q5_10','Q5_11', 'Q5_12', 'Q5_13', 'Q5_14', 
#      'Q5_15', 'Q5_16', 'Q5_17', 'Q5_18', 'Q6_01', 'Q6_02', 'Q6_03', 'Q6_04', 'Q6_05', 'Q6_06', 'Q6_07', 'Q6_08', 'Q6_09', 
#      'Q6_10', 'Q8A_01', 'Q8A_02', 'Q8A_03', 'Q8A_04', 'Q8A_05', 'Q8A_06', 'Q8B_01', 'Q8B_02', 'Q8B_03', 'Q8B_04', 'Q8B_05', 
#      'Q8B_06', 'Q8C_01', 'Q8C_02', 'Q8C_03', 'Q8C_04', 'Q8C_05', 'Q8D_01', 'Q8D_02', 'Q8D_03', 'Q8D_04', 'Q8D_05', 'Q8E_01', 
#      'Q8E_02', 'Q8E_03', 'Q8E_04', 'Q8F_01', 'Q8F_02', 'Q8F_03', 'Q8F_04', 'Q8F_05', 'Q8F_06', 'Q8F_07', 'Q8G_01', 'Q8G_02', 
#      'Q8G_03', 'Q8G_04', 'Q8G_05', 'Q8G_06', 'Q8G_07', 'Q8G_1', 'Q8G_2', 'Q8G_3', 'Q8G_4', 'Q8G_5', 'Q8G_6', 'Q8G_7','Q8G_8',
#      'Q8G_9']
# values = ['q5_01', 'q5_02', 'q5_03', 'q5_04', 'q5_05', 'q5_06', 'q5_07', 'q5_08', 'q5_09', 'q5_10', 'q5_11', 'q5_12', 'q5_13', 
#      'q5_14', 'q5_15', 'q5_16', 'q5_17', 'q5_18', 'q6_01', 'q6_02', 'q6_03', 'q6_04', 'q6_05', 'q6_06', 'q6_07', 'q6_08', 
#      'q6_09', 'q6_10', 'q8a_01', 'q8a_02', 'q8a_03', 'q8a_04', 'q8a_05', 'q8a_06', 'q8b_01', 'q8b_02', 'q8b_03', 'q8b_04', 
#      'q8b_05', 'q8b_06', 'q8c_01', 'q8c_02', 'q8c_03', 'q8c_04', 'q8c_05', 'q8d_01', 'q8d_02', 'q8d_03', 'q8d_04', 'q8d_05', 
#      'q8e_01', 'q8e_02', 'q8e_03', 'q8e_04', 'q8f_01', 'q8f_02', 'q8f_03', 'q8f_04', 'q8f_05', 'q8f_06', 'q8f_07', 'q8g_01',
#      'q8g_02', 'q8g_03', 'q8g_04', 'q8g_05', 'q8g_06', 'q8g_07', 'q8g_1', 'q8g_2', 'q8g_3', 'q8g_4', 'q8g_5', 'q8g_6', 'q8g_7',
#      'q8g_8','q8g_9']
# rename_dict = dict(zip(keys, values))

# %%
cf7.head(1)
# Out:
#            ID      reg1                                    q3 q4_01 q4_02 q4_03 q4_04 q5_01 q5_02 q5_03 q5_04          q5_05 q5_06 q5_07          q5_08 q5_09 q5_10           q5_11 q5_12 q5_13          q5_14 q5_15          q5_16          q5_17          q5_18 q6_01          q6_02           q6_03 q6_04          q6_05          q6_06 q6_07 q6_08          q6_09 q6_10               q7_01               q7_02         q8a_01          q8a_02 q8a_03         q8a_04         q8a_05         q8a_06          q8b_01          q8b_02          q8b_03          q8b_04         q8b_05          q8b_06          q8c_01          q8c_02          q8c_03          q8c_04 q8c_05         q8d_01         q8d_02          q8d_03          q8d_04          q8d_05          q8e_01          q8e_02          q8e_03          q8e_04          q8f_01          q8f_02          q8f_03 q8f_04         q8f_05 q8f_06 q8f_07 q8g_01 q8g_02          q8g_03 q8g_04 q8g_05 q8g_06          q8g_07         q8g_08        q10        q12  \
# 0  1000000007  Manitoba  City or town of 100,000 to 1,000,000     2     2     2     2     2     4     4     4  5 - Very good     2     2  1 - Very poor     2     2  Does not apply     4     2  5 - Very good     4  5 - Very good  5 - Very good  5 - Very good     4  5 - Very good  Does not apply     2  5 - Very good  5 - Very good     2     4  5 - Very good     2  5 - Strongly agree  5 - Strongly agree  5 - Very good  Does not apply   None  5 - Very good  5 - Very good  5 - Very good  Does not apply  Does not apply  Does not apply  Does not apply  1 - Very poor  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply      4  5 - Very good  5 - Very good  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply      2  5 - Very good      2      2      4   None  Does not apply      4      2      3  Does not apply  1 - Very poor  Telephone  Telephone
#
#                                  q13        q14         q15              q16_01                 q16_02              q16_03             q17a_01             q17a_02             q17a_03             q17a_04                q17a_05  q17aa q17b_01 q17b_02 q17b_03 q17b_04 q17b_05 q17b_06 q17b_07  q17bb q17c_01 q17c_02 q17c_03 q17c_04  q17cc                 q18_01                 q18_02                 q18_03                 q18_04                 q18_05                 q18_06                 q18_07 q18b_01 q18b_02 q18b_03 q18b_04         q18b_05 q18b_06 q18b_07 q18b_08 q18c_01 q18c_02                 q19_01                 q19_02              q19_03                 q19_04                 q19_05                 q19_06                 q19_07                 q19_08                 q19_09          q19_10                 q19_11   q19_12                 q20_01                 q20_02                 q20_03                 q20_04                 q20_05                 q20_06                 q20_07  \
# 0  Telephone with a live person only  Telephone  Don't know  5 - Strongly agree  1 - Strongly disagree  5 - Strongly agree  5 - Strongly agree  5 - Strongly agree  5 - Strongly agree  5 - Strongly agree  1 - Strongly disagree 60.000    None    None    None    None    None    None    None    NaN    None    None    None    None    NaN  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree       2       4       2       4  Does not apply       2       4       2    None    None  1 - Strongly disagree  1 - Strongly disagree  5 - Strongly agree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  Does not apply  1 - Strongly disagree  (DK/NS)  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree
#
#     q22   q23   q24 q25_01 q25_02 q26 q28_01 q28_02 q28_03 q28_04 resp_gen     resp_age                                   q29    q30                   q31                                   q32   q33                                 q34 q35                       q36                 q37
# 0  None  None  None   None   None  No   None   None   None   None     Male  35-44 years  A member of a visible minority group  Other  Less than five years  Post-graduate or professional degree  None  Paid employment, full or part-time  No  Both at home and at work  $30,000 to $49,999

# %%
##CF8
# to dictionary
#d = cf8_ques_id.set_index('Questions').to_dict()['ques_id']
d = pathos_cl_master_prod_serv_cf7.set_index('dim_value_name').to_dict()

cf7_ques_id_list = pathos_cl_master_prod_serv_cf7['dim_val_id'].tolist()
cf7_ques_list = pathos_cl_master_prod_serv_cf7['dim_value_name'].tolist()

#index of columns
[cf7.columns.get_loc(c) for c in cf7_ques_list if c in cf7]

#copy of dataframe
cf7_temp = cf7.iloc[:,[cf7.columns.get_loc(c) for c in cf7_ques_list if c in cf7][0]:[cf7.columns.get_loc(c) for c in cf7_ques_list if c in cf7][-1]+1].copy()

#rename columns in cf8_temp
cf7_temp.columns = cf7_temp.columns.to_series().map(d['dim_val_id'])

#concatenation
cf7 = pd.concat([cf7, cf7_temp], axis=1)

# rename id
cf7 = cf7.rename(columns={'id': 'respondent_id'})

# %%
cf7.head(2)
# Out:
#            ID      reg1                                        q3 q4_01           q4_02 q4_03          q4_04          q5_01 q5_02           q5_03           q5_04           q5_05          q5_06 q5_07          q5_08 q5_09           q5_10           q5_11          q5_12           q5_13           q5_14           q5_15           q5_16          q5_17           q5_18           q6_01          q6_02           q6_03           q6_04           q6_05           q6_06 q6_07 q6_08          q6_09 q6_10               q7_01               q7_02          q8a_01          q8a_02 q8a_03          q8a_04          q8a_05          q8a_06          q8b_01          q8b_02          q8b_03          q8b_04          q8b_05          q8b_06          q8c_01          q8c_02          q8c_03          q8c_04          q8c_05          q8d_01          q8d_02          q8d_03          q8d_04          q8d_05          q8e_01          q8e_02          q8e_03          q8e_04          q8f_01          q8f_02          q8f_03  \
# 0  1000000007  Manitoba      City or town of 100,000 to 1,000,000     2               2     2              2              2     4               4               4   5 - Very good              2     2  1 - Very poor     2               2  Does not apply              4               2   5 - Very good               4   5 - Very good  5 - Very good   5 - Very good               4  5 - Very good  Does not apply               2   5 - Very good   5 - Very good     2     4  5 - Very good     2  5 - Strongly agree  5 - Strongly agree   5 - Very good  Does not apply   None   5 - Very good   5 - Very good   5 - Very good  Does not apply  Does not apply  Does not apply  Does not apply   1 - Very poor  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply               4   5 - Very good   5 - Very good  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply
# 1  1000000008   Alberta  City or town of 1,000,000 people or more     4  Does not apply     3  5 - Very good  5 - Very good     4  Does not apply  Does not apply  Does not apply  5 - Very good     4              3     3  Does not apply   5 - Very good  5 - Very good  Does not apply  Does not apply  Does not apply  Does not apply  5 - Very good  Does not apply  Does not apply              4               4  Does not apply  Does not apply  Does not apply     3     4  5 - Very good     3                   3                   4  Does not apply  Does not apply   None  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply   5 - Very good
#
#            q8f_04          q8f_05 q8f_06 q8f_07 q8g_01 q8g_02          q8g_03 q8g_04 q8g_05          q8g_06          q8g_07          q8g_08                                 q10                                 q12                                q13                                 q14         q15              q16_01                 q16_02              q16_03             q17a_01             q17a_02             q17a_03             q17a_04                q17a_05  q17aa q17b_01 q17b_02 q17b_03 q17b_04 q17b_05 q17b_06 q17b_07  q17bb q17c_01                q17c_02 q17c_03         q17c_04  q17cc                 q18_01                 q18_02                 q18_03                 q18_04                 q18_05                 q18_06                 q18_07             q18b_01             q18b_02             q18b_03             q18b_04             q18b_05             q18b_06             q18b_07             q18b_08 q18c_01 q18c_02                 q19_01                 q19_02              q19_03  \
# 0               2   5 - Very good      2      2      4   None  Does not apply      4      2               3  Does not apply   1 - Very poor                           Telephone                           Telephone  Telephone with a live person only                           Telephone  Don't know  5 - Strongly agree  1 - Strongly disagree  5 - Strongly agree  5 - Strongly agree  5 - Strongly agree  5 - Strongly agree  5 - Strongly agree  1 - Strongly disagree 60.000    None    None    None    None    None    None    None    NaN    None                   None    None            None    NaN  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree                   2                   4                   2                   4      Does not apply                   2                   4                   2    None    None  1 - Strongly disagree  1 - Strongly disagree  5 - Strongly agree
# 1  Does not apply  Does not apply      4   None      3   None  Does not apply      4      4  Does not apply  Does not apply  Does not apply  Visit an office or service counter  Visit an office or service counter                               None  Visit an office or service counter  Don't know      Does not apply                      2      Does not apply                None                None                None                None                   None    NaN    None    None    None    None    None    None    None    NaN       2  1 - Strongly disagree       3  Does not apply 15.000     5 - Strongly agree     5 - Strongly agree                      4     5 - Strongly agree     5 - Strongly agree     5 - Strongly agree     5 - Strongly agree  5 - Strongly agree  5 - Strongly agree  5 - Strongly agree  5 - Strongly agree  5 - Strongly agree  5 - Strongly agree  5 - Strongly agree  5 - Strongly agree    None    None     5 - Strongly agree     5 - Strongly agree  5 - Strongly agree
#
#                   q19_04                 q19_05                 q19_06                 q19_07                 q19_08                 q19_09          q19_10                 q19_11   q19_12                 q20_01                 q20_02                 q20_03                 q20_04                 q20_05                 q20_06                 q20_07   q22   q23   q24 q25_01 q25_02 q26 q28_01 q28_02 q28_03 q28_04 resp_gen     resp_age                                   q29      q30                   q31                                   q32   q33                                 q34 q35                       q36                 q37         6101.0 6102.0          6103.0             NaN             NaN         6106.0 6107.0            NaN 6109.0          6110.0             NaN            NaN          6113.0             NaN          6115.0          6116.0         6117.0             NaN             NaN         6120.0          6121.0             NaN          6123.0          6124.0 NaN NaN  \
# 0  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  Does not apply  1 - Strongly disagree  (DK/NS)  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  1 - Strongly disagree  None  None  None   None   None  No   None   None   None   None     Male  35-44 years  A member of a visible minority group    Other  Less than five years  Post-graduate or professional degree  None  Paid employment, full or part-time  No  Both at home and at work  $30,000 to $49,999              2      4               4               4   5 - Very good              2      2  1 - Very poor      2               2  Does not apply              4               2   5 - Very good               4   5 - Very good  5 - Very good   5 - Very good               4  5 - Very good  Does not apply               2   5 - Very good   5 - Very good   2   4
# 1     5 - Strongly agree     5 - Strongly agree                      4     5 - Strongly agree     5 - Strongly agree     5 - Strongly agree  Does not apply     5 - Strongly agree  (DK/NS)     5 - Strongly agree     5 - Strongly agree     5 - Strongly agree                      4     5 - Strongly agree         Does not apply     5 - Strongly agree  None  None  None   None   None  No   None   None   None   None     Male  45-54 years                An Aboriginal Canadian  English           All my life                 Completed high school  None  Paid employment, full or part-time  No  Both at home and at work  $30,000 to $49,999  5 - Very good      4  Does not apply  Does not apply  Does not apply  5 - Very good      4              3      3  Does not apply   5 - Very good  5 - Very good  Does not apply  Does not apply  Does not apply  Does not apply  5 - Very good  Does not apply  Does not apply              4               4  Does not apply  Does not apply  Does not apply   3   4
#
#           6127.0 NaN                 NaN                 NaN          6129.0          6130.0 6131.0             NaN             NaN          6134.0          6135.0             NaN          6137.0          6138.0             NaN             NaN          6141.0             NaN          6143.0          6144.0          6145.0             NaN             NaN          6148.0          6149.0             NaN          6151.0          6152.0             NaN             NaN          6155.0             NaN          6157.0          6158.0          6159.0 NaN   NaN 6162.0   NaN             NaN 6165.0 NaN          6167.0          6168.0
# 0  5 - Very good   2  5 - Strongly agree  5 - Strongly agree   5 - Very good  Does not apply   None   5 - Very good   5 - Very good   5 - Very good  Does not apply  Does not apply  Does not apply  Does not apply   1 - Very poor  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply               4   5 - Very good   5 - Very good  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply               2   5 - Very good   2     2      4  None  Does not apply      4   2               3  Does not apply
# 1  5 - Very good   3                   3                   4  Does not apply  Does not apply   None  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply  Does not apply   5 - Very good  Does not apply  Does not apply   4  None      3  None  Does not apply      4   4  Does not apply  Does not apply

# %% [markdown]
# ## Adding Dimension ID

# %% [markdown]
# ### Adding time dimension to cf8

# %%
cf7.insert(0, 'TimeStamp', pd.to_datetime('2014-01-23 16:46:22').replace(microsecond=0))
cf7['Qtr'] = pd.to_datetime(cf7.TimeStamp).dt.quarter
cf7['year'] = cf7['TimeStamp'].dt.year
cf7['year']= cf7["year"].astype(str)
cf7['Qtr']=cf7["Qtr"].astype(str)
cf7['Period_id'] = cf7[['year', 'Qtr']].agg('_0'.join, axis=1)

# %%
#REPLACING BRAND NAME WITH BRAND ID
try:
    s = cf7.year.replace(pathos_cl_master_time.set_index('dim_value_name')['dim_val_id'])
    cf7['time_id'] = s
except:
    print('not available')

# %% [markdown]
# ### cf8 & channel dimension

# %%
cf7['channel']= cf7.q10.replace({'Telephone': 'Telephone', 'Visit an office or service counter':'In-person',
       'Online/website': 'Online','E-mail':'Online', 'Regular mail': 'Mail',
       'Text message (SMS)':'Telephone', 'Social media (Twitter, Facebook)':'Online', 'Kiosk':'In-person',
       'Fax':'Telephone', 'Mobile app':'Online', 'Visit from a government employee':'In-person', 'None of the above/No others':'unknown',
                                np.nan:'unknown'})

# %%
#REPLACING BRAND NAME WITH BRAND ID
try:
    s = cf7.channel.replace(pathos_cl_master_channel.set_index('dim_value_name')['dim_val_id'])
    cf7['channel_id'] = s
except:
    print('not available')

# %% [markdown]
# ### Demographic reference

# %%
cf7 = cf7.rename(columns={'resp_gen': 'gender'})
cf7 = cf7.rename(columns = {'resp_age':'age'})
cf7 = cf7.rename(columns= {'q34':'occupation'})
cf7 = cf7.rename(columns={'q37':'income'})

# %%
cf7.gender .unique()
# Out:
# array(['Male', 'Female', '(DK/NS)'], dtype=object)

# %%
cf7['gender']= cf7.gender.replace({'(DK/NS)':'unknown',
                                np.nan:'unknown'})

# %%
# int to string
cf7.gender = cf7.gender.astype(str)

#REPLACING BRAND NAME WITH BRAND ID
try:
    s = cf7.gender.replace(pathos_cl_master_gender.set_index('dim_value_desc')['dim_val_id'])
    cf7['gender_id'] = s
except:
    print('not available')

# %% [markdown]
# # age dimension

# %%
cf7['age']= cf7.age.replace({'(DK/NS)':'-1',
                                np.nan:'-1', '75+  years':'7', '35-44 years':'3', '45-54 years':'4', '25-34 years':'2', '18-24 years':'1',
       '55-64 years':'5', '65-74 years':'6'})

# %%
cf7['age'].unique()
# Out:
# array(['3', '4', '2', '1', '5', '6', '7', '-1'], dtype=object)

# %%
# int to string
cf7.age = cf7.age.astype(str)

#REPLACING BRAND NAME WITH BRAND ID
# here we have used dim_value_desc instead of dim_value_name
try:
    s = cf7.age.replace(pathos_cl_master_age.set_index('dim_value_name')['dim_val_id'])
    cf7['age_id'] = s
except:
    print('not available')

# %%
cf7['age_id'].unique()
# Out:
# array([803., 804., 802., 801., 805., 806., 807., 808.])

# %% [markdown]
# # occupation dimension

# %%
cf7['occupation']= cf7.occupation.replace({'Paid employment, part time or full time':'1',
    'Paid employment, full or part-time':'1',
'Student, full or part time':'2',
'Looking for work':'3',
'Homemaker':'4',
'Retired':'5',
'Other':'6',
'Prefer not to answer':'7',
'(DK/NS)':'-1', np.nan:'-1'})

# %%
cf7.occupation.unique()
# Out:
# array(['1', '2', '4', '6', '5', '3', '-1'], dtype=object)

# %%
# int to string
cf7.occupation = cf7.occupation.astype(str)

#REPLACING BRAND NAME WITH BRAND ID
try:
    s = cf7.occupation.replace(pathos_cl_master_occupation.set_index('dim_value_name')['dim_val_id'])
    cf7['occupation_id'] = s
except:
    print('not available')

# %%
cf7['occupation_id'].unique()
# Out:
# array([901., 902., 904., 906., 905., 903., 908.])

# %% [markdown]
# # income

# %%
cf7.income.unique()
# Out:
# array(['$30,000 to $49,999', '$110,000 to $149,999', '$20,000 to $29,999',
#        '$70,000 to $89,999', '$50,000 to $69,999', '$10,000 to $19,999',
#        '$150,000 or more', 'Under $10,000', '$90,000 to $109,999',
#        '(DK/NS)'], dtype=object)

# %%
cf7['income']= cf7.income.replace({'(DK/NS)':'unknown', np.nan:'unknown'})

# %%
# int to string
cf7.income = cf7.income.astype(str)

#REPLACING BRAND NAME WITH BRAND ID
try:
    s = cf7.income.replace(pathos_cl_master_income.set_index('dim_value_desc')['dim_val_id'])
    cf7['income_id'] = s
except:
    print('not available')

# %%
pathos_cl_master_prod_serv_cf7
# Out:
#     dim_val_id dim_value_name                                     dim_value_desc dim_active_reporting dim_active_processsing child_record  parent_record_id  hierarchy_level    cat_mpi                        category                       created_on created_by                       updated_on updated_by
# 0     6101.000          q5_01   Drinking Water provided to you at your residence                    Y                      Y            N        -99999.000            1.000  Municipal              Municipal/Regional 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 1     6102.000          q5_02             Garbage collection or garbage disposal                    Y                      Y            N        -99999.000            1.000  Municipal              Municipal/Regional 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 2     6103.000          q5_03                         Recycling (blue/black bin)                    Y                      Y            N        -99999.000            1.000  Municipal              Municipal/Regional 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 5     6106.000          q5_06                   Sewage and waste water treatment                    Y                      Y            N        -99999.000            1.000  Municipal              Municipal/Regional 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 6     6107.000          q5_07        Municipal or regional snow removal services                    Y                      Y            N        -99999.000            1.000  Municipal              Municipal/Regional 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 8     6109.000          q5_09  Traffic management in your municipality or region                    Y                      Y            N        -99999.000            1.000  Municipal              Municipal/Regional 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 9     6110.000          q5_10  Municipally or regionally-run public transit (...                    Y                      Y            N        -99999.000            1.000  Municipal              Municipal/Regional 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 12    6113.000          q5_13                    Municipal parks and campgrounds                    Y                      Y            N        -99999.000            1.000  Municipal              Municipal/Regional 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 14    6115.000          q5_15                       Municipal or regional courts                    Y                      Y            N        -99999.000            1.000  Municipal              Municipal/Regional 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 15    6116.000          q5_16                                    Fire Department                    Y                      Y            N        -99999.000            1.000  Municipal              Municipal/Regional 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 16    6117.000          q5_17                       Municipal or regional police                    Y                      Y            N        -99999.000            1.000  Municipal              Municipal/Regional 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 19    6120.000          q6_02                      Provincial/territorial police                    Y                      Y            N        -99999.000            1.000  Municipal  Provincial/Territorial/Federal 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 20    6121.000          q6_03                                               RCMP                    Y                      Y            N        -99999.000            1.000     Police  Provincial/Territorial/Federal 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 22    6123.000          q6_05  Provincially/territorially-run EMS or ambulanc...                    Y                      Y            N        -99999.000            1.000  Municipal  Provincial/Territorial/Federal 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 23    6124.000          q6_06                         Custom and Border Services                    Y                      Y            N        -99999.000            1.000  Municipal  Provincial/Territorial/Federal 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 26    6127.000          q6_09   Provincial/territorial museums or heritage sites                    Y                      Y            N        -99999.000            1.000  Municipal  Provincial/Territorial/Federal 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 28    6129.000         q8a_01           Injured workers compensation or programs                    Y                      Y            N        -99999.000            1.000  Municipal  Provincial/Territorial/Federal 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 29    6130.000         q8a_02  A provincial or territorial student loan and/o...                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 30    6131.000         q8a_03  A retirement pension from la Regie des rentes ...                    Y                      Y            N        -99999.000            1.000  Insurance                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 33    6134.000         q8a_06            A municipal or regional housing subsidy                    Y                      Y            N        -99999.000            1.000  Insurance                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 34    6135.000         q8b_01  Living or staying in public housing, hostel an...                    Y                      Y            N        -99999.000            1.000  Insurance                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 36    6137.000         q8b_03  Living or having a close family member living ...                    Y                      Y            N        -99999.000            1.000  Insurance                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 37    6138.000         q8b_04  Living or having a close family member living ...                    Y                      Y            N        -99999.000            1.000  Insurance                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 40    6141.000         q8c_01  Registered for a provincial/territorial govern...                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 42    6143.000         q8c_03  Registered for a hiring incentive program prov...                    Y                      Y            N        -99999.000            1.000  Insurance                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 43    6144.000         q8c_04  Registered for employment or career planning s...                    Y                      Y            N        -99999.000            1.000     Police                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 44    6145.000         q8c_05  Visited a job bank (such as workbc.ca) provide...                    Y                      Y            N        -99999.000            1.000  Insurance                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 47    6148.000         q8d_03         A provincial/territorial childcare subsidy                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 48    6149.000         q8d_04                               A recreation subsidy                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 50    6151.000         q8e_01  Contacted a provincial/territorial online or t...                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 51    6152.000         q8e_02  Registered for counselling and/or family servi...                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 54    6155.000         q8f_01  Information services of your municipality or r...                    Y                      Y            N        -99999.000            1.000  Insurance                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 56    6157.000         q8f_03  Information services of your province or terri...                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 57    6158.000         q8f_04  Municipal or regional road information (e.g., ...                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 58    6159.000         q8f_05  Provincial/territorial highway or road informa...                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 61    6162.000         q8g_01                                  A building permit                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 64    6165.000         q8g_04              Driver's licensing testing or renewal                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 66    6167.000         q8g_06  Motor vehicle registration, transfer of ownership                    Y                      Y            N        -99999.000            1.000  Insurance                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 67    6168.000         q8g_07                              Automobile insurance]                    Y                      Y            N        -99999.000            1.000     Police                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 68    6169.000          q8g_1  Information services of your municipality, inc...                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 71    6172.000          q8g_4  Information services of your province or terri...                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 74    6175.000          q8g_7  Municipal or regional planning or land develop...                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 75    6176.000          q8g_8  Your municipality with a question about, or to...                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System
# 76    6177.000          q8g_9  Contacted the Canada Revenue Agency with a que...                    Y                      Y            N        -99999.000            1.000  Municipal                      Government 2021-06-20 18:22:20.350190+00:00     System 2021-06-20 18:22:20.350190+00:00     System

# %% [markdown]
# # Jurisdiction

# %%
#REPLACING BRAND NAME WITH BRAND ID
try:
    s = cf7.jurisdiction.replace(pathos_cl_master_country.set_index('dim_value_name')['dim_val_id'])
    cf7['location_id'] = s
except:
    print('not available')
# Out:
# not available

# %%
cf7 = cf7.rename(columns={'ID': 'id'})    #rename
pathos_cl_master_prod_serv_cf7_list = pathos_cl_master_prod_serv_cf7['dim_val_id'].tolist()
common = list(set(pathos_cl_master_prod_serv_cf7_list).intersection(cf7.columns))
table_list = ['id', 'gender_id', 'age_id', 'occupation_id', 'income_id', 'channel_id', 'time_id']
final_list = table_list + common
cf7 = cf7[final_list]

# %% [markdown]
# # Applying filters to Main DataFrame

# %%
try:
    available_time = list(pathos_cl_master_time['dim_val_id'])
except:
    print('not available')
        
try:
    available_age = list(pathos_cl_master_age['dim_val_id'])
except:
    print('not available')
        
try:
    available_occupation = list(pathos_cl_master_occupation['dim_val_id'])
except:
    print('not available')
        
try:
    available_gender = list(pathos_cl_master_gender['dim_val_id'])
except:
    print('not available')
        
try:
    available_income = list(pathos_cl_master_income['dim_val_id'])
except:
    print('not available')
        
try:
    available_channel = list(pathos_cl_master_channel['dim_val_id'])
except:
    print('not available')

# %% [markdown]
# ### Applying Filter

# %%
try:
    cf7 = cf7.loc[cf7['time_id'].isin (available_time)]
except:
    print('not available')
        
try:
    cf7 = cf7.loc[cf7['age_id'].isin (available_age)]
except:
    print('not available')
        
try:
    cf7 = cf7.loc[cf7['gender_id'].isin (available_gender)]
except:
    print('not available')

try:
    cf7 = cf7.loc[cf7['income_id'].isin (available_income)]
except:
    print('not available')

try:
    cf7 = cf7.loc[cf7['occupation_id'].isin (available_occupation)]
except:
    print('not available')

try:
    cf7 = cf7.loc[cf7['channel_id'].isin (available_channel)]
except:
    print('not available')

# %%
ques_dict = pd.Series(pathos_cl_master_prod_serv_cf7.dim_value_name.values,index=pathos_cl_master_prod_serv_cf7.dim_val_id).to_dict()

# %%
cf7.rename(columns=ques_dict, inplace=True)

# %%
# removing first two integers from ID
cf7['id'] = cf7['id'].astype(str)
cf7['id'] = cf7['id'].str[2:]
cf7['id'] = pd.to_numeric(cf7['id'], errors='coerce')
cf7 = (cf7[cf7['id'].notnull()])
cf7['id'] = cf7['id'].astype(int)

# %%
df = pd.concat([cf8,cf7], axis=0, ignore_index=True)

# %%
df.shape
# Out:
# (4477, 90)

# %% [markdown]
# # Adding Version

# %%
current_version = list(pathos_cl_master_prod_ver['pathos_ref_prd_rel_unique_id'])

# %%
df['version_id'] = current_version[0]

# %%
current_version
# Out:
# [17994.0]

# %%
df = df[df['id'].notna()]

# %% [markdown]
# # Transaction table

# %%
connection = pg.connect('postgresql://aidatabases:Aidatabases#@34.93.95.15:5432/pathos_db')

engine = create_engine('postgresql://aidatabases:Aidatabases#@34.93.95.15:5432/pathos_db')

# %%
try:
    truncate_table(table_name= 'iccs_transaction_table', schema = dim_schema)
except:
    print("not available")

# %%
df.gender_id.value_counts()
# Out:
# 701.000    4477
# Name: gender_id, dtype: int64

# %%
df['pathos_transaction_id']=list(range(1, df.shape[0]+1))

# %%
# for i in df.columns:
#     a = df[i].unique()
#     print(a)

# %%
df = df.astype(str)

# %%
di = {'1 - Very poor':1, '5 - Very good':5, '(DK/NS)': None, 'Does not apply': None}

# %%
for i in df.columns:
    df = df.replace({i: di})

# %%
df.shape
# Out:
# (4477, 92)

# %%
df['q8a_03'].unique()
# Out:
# array(['nan', '4.0', '5.0', '3.0', '1.0', '2.0'], dtype=object)

# %%
di = {'None':np.nan}
for i in df.columns:
    df = df.replace({i: di})

# %%
df = df.fillna(value=np.nan)

# %%
df.replace(to_replace=[None], value=np.nan, inplace=True)

# %%
push_table_pgres(df, df_name = 'iccs_transaction_table', schema= dim_schema)

# %%
df.time_id.value_counts()
# Out:
# 810016.0    2303
# 810012.0    2174
# Name: time_id, dtype: int64
