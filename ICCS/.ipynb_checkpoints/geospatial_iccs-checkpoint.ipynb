# %%
from pathos_config import *

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x) #to supress scientific notation
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
summary_table = load_data('iccs_summary_table', 'pathos_iccs_schema', connection)

# %%
# import geopandas as gpd
# geo_data = gpd.read_file('canada_administrative_province_state_boundary.geojson')

# %%
connection = pg.connect('postgresql://aidatabases:Aidatabases#@65.1.96.15:5433/geopostgres')
engine = create_engine('postgresql://aidatabases:Aidatabases#@65.1.96.15:5433/geopostgres')
canada_geojson = load_data('canada_provinces', 'public', connection)

# %%
canada_geojson.columns
# Out:
# Index(['province', 'geojson'], dtype='object')

# %%
canada_geojson.shape
# Out:
# (26987, 2)

# %%
# from shapely.geometry import Polygon
# from shapely.ops import cascaded_union

# polygon1 = Polygon([(0, 0), (5, 3), (5, 0)])
# polygon2 = Polygon([(0, 0), (3, 10), (3, 0)])

# polygons = [polygon1, polygon2]

# u = cascaded_union(polygons)

# %%
canada_geojson_dict = canada_geojson.geojson.apply(eval)

# %%
canada_geojson_dict.shape[0]
# Out:
# 26987

# %%
canada_geojson_list = []
for i in range(canada_geojson_dict.shape[0]):
    a = canada_geojson_dict[i].get('geometry').get('coordinates')
    canada_geojson_list.append(a)

# %%
canada_geojson['coordinates']= canada_geojson_list

# %%
canada_geojson['coordinates'] = canada_geojson.coordinates.str[0]

# %%
canada_geojson.coordinates.str[0]
# Out:
# 0        [[-57.402578932, 54.149641862], [-57.384313644...
# 1        [[-55.431434415, 51.575233953], [-55.43135558,...
# 2        [[-61.369099864, 56.906610802], [-61.377477553...
# 3        [[-54.103688182, 49.744634804], [-54.10364611,...
# 4        [[-53.527237714, 48.197821778], [-53.527359325...
#                                ...
# 26982    [[-103.903994524, 70.695360654], [-103.9026347...
# 26983    [[-103.904363711, 70.697039826], [-103.9035197...
# 26984    [[-103.881182088, 70.757423778], [-103.8802970...
# 26985    [[-103.218269419, 70.66162808], [-103.21909741...
# 26986    [[-103.990433183, 70.729933431], [-103.9907620...
# Name: coordinates, Length: 26987, dtype: object

# %%
#canada_provinces.rename(columns={'province':'location'}, inplace=True)

# %%
canada_geojson
# Out:
#                         province                                            geojson                                        coordinates
# 0      Newfoundland and Labrador  {"type" : "Polygon", "geometry" : {"type":"Pol...  [[[-57.402578932, 54.149641862], [-57.38431364...
# 1      Newfoundland and Labrador  {"type" : "Polygon", "geometry" : {"type":"Pol...  [[[-55.431434415, 51.575233953], [-55.43135558...
# 2      Newfoundland and Labrador  {"type" : "Polygon", "geometry" : {"type":"Pol...  [[[-61.369099864, 56.906610802], [-61.37747755...
# 3      Newfoundland and Labrador  {"type" : "Polygon", "geometry" : {"type":"Pol...  [[[-54.103688182, 49.744634804], [-54.10364611...
# 4      Newfoundland and Labrador  {"type" : "Polygon", "geometry" : {"type":"Pol...  [[[-53.527237714, 48.197821778], [-53.52735932...
# ...                          ...                                                ...                                                ...
# ...

# %%
province_list = list(canada_geojson.province.unique())
province_list
# Out:
# ['Newfoundland and Labrador',
#  'Prince Edward Island',
#  'Nova Scotia',
#  'New Brunswick',
#  'Quebec',
#  'Ontario',
#  'Manitoba',
#  'Saskatchewan',
#  'Alberta',
#  'British Columbia',
#  'Yukon',
#  'Northwest Territories',
#  'Nunavut']

# %%
Newfoundland_list = []
Prince_list = []
Nova_list = []
New_list = []
Quebec_list = []
Ontario_list = []
Manitoba_list = []
Saskatchewan_list = []
Alberta_list = []
British_list = []
Yukon_list = []
Northwest_list = []
Nunavut_list = []

# %%
list_list = [Newfoundland_list, Prince_list, Nova_list, New_list, Quebec_list, Ontario_list, Manitoba_list, Saskatchewan_list, Alberta_list,
British_list, Yukon_list, Northwest_list, Nunavut_list]

# %%
Newfoundland_list = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == 'Newfoundland and Labrador'])
Prince_list = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == 'Prince Edward Island'])
Nova_list = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == 'Nova Scotia'])
New_list = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == 'New Brunswick'])
Quebec_list = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == 'Quebec'])
Ontario_list = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == 'Ontario'])
Manitoba_list = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == 'Manitoba'])
Saskatchewan_list = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == 'Saskatchewan'])
Alberta_list = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == 'Alberta'])
British_list = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == 'British Columbia'])
Yukon_list = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == 'Yukon'])
Northwest_list = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == 'Northwest Territories'])
Nunavut_list = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == 'Nunavut'])

# %%
# for i,j in zip(province_list,list_list) :
#     print(i)
#     a = list(canada_geojson['coordinates'].loc[canada_geojson['province'] == i])
#     print(j)
#     j.append(a)
#     #print(j)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
geo_dict = {'Newfoundland and Labrador':'{"type" : "Polygon", "geometry" : {"type":"Polygon","coordinates":' + str(Newfoundland_list[0]) +'}}',
           'Prince Edward Island':'{"type" : "Polygon", "geometry" : {"type":"Polygon","coordinates":' + str(Prince_list[0]) +'}}',
           'Nova Scotia':'{"type" : "Polygon", "geometry" : {"type":"Polygon","coordinates":' + str(Nova_list[0]) +'}}',
           'New Brunswick':'{"type" : "Polygon", "geometry" : {"type":"Polygon","coordinates":' + str(New_list[0]) +'}}',
           'Quebec':'{"type" : "Polygon", "geometry" : {"type":"Polygon","coordinates":' + str(Quebec_list[0]) +'}}',
           'Ontario':'{"type" : "Polygon", "geometry" : {"type":"Polygon","coordinates":' + str(Ontario_list[0]) +'}}',
           'Manitoba':'{"type" : "Polygon", "geometry" : {"type":"Polygon","coordinates":' + str(Manitoba_list[0]) +'}}',
           'Saskatchewan':'{"type" : "Polygon", "geometry" : {"type":"Polygon","coordinates":' + str(Saskatchewan_list[0]) +'}}',
           'Alberta':'{"type" : "Polygon", "geometry" : {"type":"Polygon","coordinates":' + str(Alberta_list[0]) +'}}',
           'British Columbia':'{"type" : "Polygon", "geometry" : {"type":"Polygon","coordinates":' + str(British_list[0]) +'}}',
           'Yukon':'{"type" : "Polygon", "geometry" : {"type":"Polygon","coordinates":' + str(Yukon_list[0]) +'}}',
           'Northwest Territories':'{"type" : "Polygon", "geometry" : {"type":"Polygon","coordinates":' + str(Northwest_list[0]) +'}}',
           'Nunavut':'{"type" : "Polygon", "geometry" : {"type":"Polygon","coordinates":' + str(Nunavut_list[0]) +'}}'}

# %%
final_geo_canada = pd.DataFrame([geo_dict])

# %%
final_geo_canada = final_geo_canada.T

# %%
final_geo_canada.reset_index(level=0, inplace=True)

# %%
final_geo_canada.rename(columns= {'index':'location', 0: 'geojson'}, inplace=True)

# %%
final_geo_canada
# Out:
#                      location                                            geojson
# 0   Newfoundland and Labrador  {"type" : "Polygon", "geometry" : {"type":"Pol...
# 1        Prince Edward Island  {"type" : "Polygon", "geometry" : {"type":"Pol...
# 2                 Nova Scotia  {"type" : "Polygon", "geometry" : {"type":"Pol...
# 3               New Brunswick  {"type" : "Polygon", "geometry" : {"type":"Pol...
# 4                      Quebec  {"type" : "Polygon", "geometry" : {"type":"Pol...
# 5                     Ontario  {"type" : "Polygon", "geometry" : {"type":"Pol...
# 6                    Manitoba  {"type" : "Polygon", "geometry" : {"type":"Pol...
# 7                Saskatchewan  {"type" : "Polygon", "geometry" : {"type":"Pol...
# 8                     Alberta  {"type" : "Polygon", "geometry" : {"type":"Pol...
# 9            British Columbia  {"type" : "Polygon", "geometry" : {"type":"Pol...
# 10                      Yukon  {"type" : "Polygon", "geometry" : {"type":"Pol...
# ...

# %%
iccs_geo = pd.merge(summary_table, final_geo_canada, on="location", how= 'left' )

# %%
iccs_geo
# Out:
#       pathos_summary_id review_id client_transaction_id client_transaction_date message_desc  q5a_1  q5a_2  q5a_3 q5a_4 q5a_5  q5a_6  q5a_7 q5a_8  q5a_9  q5a_10 q5b_1 q5b_2  q5b_3 q5b_4  q5b_5  q5b_6  q5b_7 q5b_8 q5b_9  q6_1  q6_2  q6_3  q6_4  q6_5  q6_6  q6_7  q6_8  q6_9  q6_10  q6_11  q8a_1 q8a_2 q8a_3  q8a_4  q8a_5 q8a_6  q8a_7  q8a_8 q8a_9 q8b_1  q8b_2 q8b_3  q8b_4  q8b_5  q8b_6 q8c_1 q8c_2  q8c_3  q8c_4 q8c_5  q8c_6  q8d_1 q8d_2 q8d_3  q8d_4 q8d_5  q8e_1  q8e_2  q8e_3 q8e_4 q8f_1  q8f_2 q8f_3 q8f_4  q8f_5 q8f_6  q8f_7  q8f_8  q8g_1 q8g_2 q8g_3  q8g_4 q8g_5 q8g_6  q8g_7  q8g_8  q8g_9  q5_01  q5_02  q5_03 q5_04 q5_05  q5_06  q5_07 q5_08  q5_09  q5_10 q5_11 q5_12  q5_13 q5_14  q5_15  q5_16  q5_17 q5_18 q6_01  q6_02  q6_03 q6_04  q6_05  q6_06 q6_07 q6_08  q6_09  q8a_01  q8a_02  q8a_03 q8a_04 q8a_05  q8a_06  q8b_01 q8b_02  q8b_03  q8b_04 q8b_05 q8b_06  q8c_01 q8c_02  q8c_03  q8c_04  q8c_05 q8d_01 q8d_02  q8d_03  q8d_04 q8d_05  q8e_01  q8e_02 q8e_03 q8e_04  q8f_01 q8f_02  q8f_03  \
# ...

# %%
# connection = pg.connect('postgresql://aidatabases:Aidatabases#@65.1.96.15:5432/pathos_db')
# engine = create_engine('postgresql://aidatabases:Aidatabases#@65.1.96.15:5432/pathos_db')

# %%
# #truncate_table(table_name= 'iccs_geo', schema = 'pathos_iccs_schema')

# push_table_pgres(iccs_geo, df_name = 'iccs_geo', schema= 'pathos_iccs_schema')

# %%
connection = pg.connect('postgresql://aidatabases:Aidatabases#@65.1.96.15:5433/geopostgres')
engine = create_engine('postgresql://aidatabases:Aidatabases#@65.1.96.15:5433/geopostgres')

# %%
iccs_geo.to_sql('iccs_summary_geojson', con=engine, index=False, if_exists= 'append')

# %%
iccs_geo.location.unique()
# Out:
# array(['Northwest Territories', 'Yukon', 'City of Toronto', 'Ontario',
#        'Peel', 'Federal Government', 'Manitoba', 'Alberta',
#        'British Columbia', 'Nova Scotia', 'Prince Edward Island'],
#       dtype=object)

# %%
from geopandas import GeoDataFrame
from shapely.geometry import Point

# geometry = [Point(xy) for xy in zip(df.Lon, df.Lat)]
# df = df.drop(['Lon', 'Lat'], axis=1)
iccs_geo = GeoDataFrame(iccs_geo, crs="EPSG:4326", geometry=geometry)

# %%
import geopandas
from sqlalchemy import create_engine

# Set up database connection engine
engine = create_engine('postgresql://aidatabases:Aidatabases#@65.1.96.15:5433/geopostgres')

# Load data into GeoDataFrame, e.g. from shapefile
#geodata = geopandas.read_file("shapefile.shp")

# GeoDataFrame to PostGIS
iccs_geo.to_postgis(
    con=engine,
    name="iccs_geo"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-fb09f4e92b20> in <module>
#       9
#      10 # GeoDataFrame to PostGIS
# ---> 11 iccs_geo.to_postgis(
#      12     con=engine,
#      13     name="iccs_geo"
#
# ~\anaconda3\lib\site-packages\geopandas\geodataframe.py in to_postgis(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    1681
#    1682         """
# -> 1683         geopandas.io.sql._write_postgis(
#    1684             self, name, con, schema, if_exists, index, index_label, chunksize, dtype
#    1685         )
#
# ~\anaconda3\lib\site-packages\geopandas\io\sql.py in _write_postgis(gdf, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     400
#     401     # Convert geometries to EWKB
# --> 402     gdf = _convert_to_ewkb(gdf, geom_name, srid)
#     403
#     404     if schema is not None:
#
# ...

# %%
from sqlalchemy import create_engine

from geoalchemy2 import Geometry, WKTElement

import pandas as pd

import psycopg2

import geopandas as gpd


engine = create_engine('postgresql://aidatabases:Aidatabases#@65.1.96.15:5433/geopostgres')

iccs_geo.to_postgis(con=engine, name="iccs_geo")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-70006f1580b7> in <module>
#      12 engine = create_engine('postgresql://aidatabases:Aidatabases#@65.1.96.15:5433/geopostgres')
#      13
# ---> 14 iccs_geo.to_postgis(con=engine, name="iccs_geo")
#
# ~\anaconda3\lib\site-packages\geopandas\geodataframe.py in to_postgis(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    1681
#    1682         """
# -> 1683         geopandas.io.sql._write_postgis(
#    1684             self, name, con, schema, if_exists, index, index_label, chunksize, dtype
#    1685         )
#
# ~\anaconda3\lib\site-packages\geopandas\io\sql.py in _write_postgis(gdf, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     400
#     401     # Convert geometries to EWKB
# --> 402     gdf = _convert_to_ewkb(gdf, geom_name, srid)
#     403
# ...

# %%
iccs_geo.columns
# Out:
# Index(['pathos_summary_id', 'review_id', 'client_transaction_id', 'client_transaction_date', 'message_desc', 'q5a_1', 'q5a_2', 'q5a_3', 'q5a_4', 'q5a_5',
#        ...
#        'behaviour_qual_negative_comments', 'behaviour_score', 'positive_score_by_weights', 'negative_score_by_weights', 'created_on', 'created_by', 'updated_on', 'updated_by', 'gid', 'geometry'], dtype='object', length=231)
